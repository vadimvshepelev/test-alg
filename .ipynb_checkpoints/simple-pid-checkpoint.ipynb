# %%
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from math import sin, exp
from random import random
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

n_max = 102

# Задаем ряд
price_ser_src = pd.Series([sin(x) + 10*random() for x in range(1, n_max)])
# p_ser = price_ser_src[::5]

# Находим mu (тренд)
# Простой способ -- первая разность
mu_arr = np.array([price_ser_src[i]-price_ser_src[i-1] if i > 0 else 0. for i in range(len(price_ser_src)) ])

# Находим параметры ARMA (подгоняем модель)
model = ARIMA(price_ser_src, order=(4, 0, 4))
model_fit = model.fit()
print(model_fit.summary())

# make prediction -- это пока вообще не трогаем
# yhat = model_fit.predict(len(data), len(data))
# print(yhat)

# График
plt.title("Временной ряд") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("p_n") # ось ординат
plt.grid()      # включение отображение сетки
# plt.plot(p_ser)  # построение графика
plt.plot(price_ser_src)
plt.plot(mu_arr)

# p_ser.reset_index(inplace=True, drop=True)
# p_ser

mu_arr
# Out:
# C:\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  101
# Model:                 ARIMA(4, 0, 4)   Log Likelihood                -243.122
# Date:                Wed, 30 Mar 2022   AIC                            506.244
# Time:                        15:15:30   BIC                            532.396
# Sample:                             0   HQIC                           516.831
#                                 - 101
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7949      0.138     34.757      0.000       4.525       5.065
# ar.L1         -0.1330      0.232     -0.572      0.567      -0.588       0.323
# ar.L2          0.0955      0.215      0.444      0.657      -0.326       0.517
# ar.L3          0.0177      0.210      0.084      0.933      -0.394       0.430
# ar.L4          0.7418      0.230      3.220      0.001       0.290       1.193
# ma.L1          0.0154    213.225   7.21e-05      1.000    -417.898     417.928
# ma.L2          0.0053    209.570   2.53e-05      1.000    -410.744     410.754
# ma.L3         -0.0004    211.058  -1.77e-06      1.000    -413.667     413.666
# ma.L4         -0.9903    211.497     -0.005      0.996    -415.518     413.537
# sigma2         6.8467   1460.776      0.005      0.996   -2856.222    2869.915
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.30   Jarque-Bera (JB):                 5.20
# Prob(Q):                              0.58   Prob(JB):                         0.07
# Heteroskedasticity (H):               0.98   Skew:                             0.14
# Prob(H) (two-sided):                  0.95   Kurtosis:                         1.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Python310\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# array([ 0.        , -1.45172318, -0.63232033,  3.97557631,  2.0166526 ,
#        -4.43793746,  1.35504427, -2.63207775,  6.74875967, -7.23762546,
#         3.687536  ,  0.55027199, -3.89689607,  1.71994097,  7.25321936,
#        -8.42846413, -1.68468401,  4.22911937, -3.33590355,  6.3076934 ,
#        -1.38264341,  3.40955995, -7.82241418,  6.05207288, -6.47032163,
#        -0.18515343,  0.94624271,  0.68193359,  6.66974377, -3.91518531,
#         0.50788892,  1.42818233, -2.55394508, -1.16649872,  3.12787437,
#        -3.69370484,  2.68491256, -0.25468813,  5.5228347 , -1.56077087,
#        -1.75376957,  0.58722262, -6.77351727,  2.92226657,  1.90790553,
#         0.82623342, -3.15454307, -4.09068005,  2.7814225 ,  3.56675029,
#        -5.10748755,  2.89709779,  2.18049031, -0.19344267, -0.27629593,
#         3.30360739, -6.35506866,  2.2801974 ,  0.34289068,  1.28456789,
#        -4.20931198,  4.68401945, -5.26497147,  6.63301688, -6.04182313,
#         3.49192999,  0.20582482, -2.26268794, -1.48040133, -0.66857665,
#         2.25348861,  3.26885604, -7.46732047,  8.86117734, -6.94514655,
#         6.18362126,  2.36703297, -5.58387528,  4.39818127, -8.35889526,
#         2.01178985,  6.86299796, -8.34373966,  6.57197061, -4.60138878,
#        -1.49475603,  7.42138818, -5.58331134,  1.75481752, -1.9030065 ,
#         3.61138613, -5.90928478,  6.70972512, -0.38222796, -0.10800072,
#        -5.69215353,  3.26362198,  2.24595936, -2.12504482, -0.42821135,
#         2.24309992])

# %%
from scipy.optimize import minimize, minimize_scalar
import math
import functools


def math_exp(K: float, inv: float, mu: float, i: int):
    res = -inv/K * (math.exp(K*mu*i) + math.exp(-K*mu*i) - 2) 
    return res

def f(x):
    mu = 1
    t = 1
    return -1/x*(math.exp(x*mu*t) + math.exp(-x*mu*t) - 2)





# Считаем алгоритм

inv_0 = 100
inv_ser = [inv_0]

"""
for cnt, price in enumerate(price_ser_src):
    if cnt == 0:
        continue
    f = functools.partial(math_exp, inv = inv_ser[cnt-1], mu = mu[cnt-1], i=cnt-1)    
    K = minimize_scalar(f, bounds=(-1, 1), method='bounded', ).x
    inv_ser.append(K)
    
inv_ser
"""
print(inv_ser, mu_arr)


x_arr = np.linspace(-10, 10., 100)
f_arr = np.array([f(x_arr[i]) for i in range(len(x_arr))])



# f = functools.partial(math_exp, inv = 10, mu = 1, i=1)    
plt.title("Ищем максимум") # заголовок
plt.xlabel("x") # ось абсцисс
plt.ylabel("f(x)") # ось ординат
plt.grid()      # включение отображение сетки
# plt.plot(p_ser)  # построение графика
plt.plot(x_arr, -f_arr)

x_arr, f_arr
# Out:
# [100] [ 0.         -1.45172318 -0.63232033  3.97557631  2.0166526  -4.43793746
#   1.35504427 -2.63207775  6.74875967 -7.23762546  3.687536    0.55027199
#  -3.89689607  1.71994097  7.25321936 -8.42846413 -1.68468401  4.22911937
#  -3.33590355  6.3076934  -1.38264341  3.40955995 -7.82241418  6.05207288
#  -6.47032163 -0.18515343  0.94624271  0.68193359  6.66974377 -3.91518531
#   0.50788892  1.42818233 -2.55394508 -1.16649872  3.12787437 -3.69370484
#   2.68491256 -0.25468813  5.5228347  -1.56077087 -1.75376957  0.58722262
#  -6.77351727  2.92226657  1.90790553  0.82623342 -3.15454307 -4.09068005
#   2.7814225   3.56675029 -5.10748755  2.89709779  2.18049031 -0.19344267
#  -0.27629593  3.30360739 -6.35506866  2.2801974   0.34289068  1.28456789
#  -4.20931198  4.68401945 -5.26497147  6.63301688 -6.04182313  3.49192999
#   0.20582482 -2.26268794 -1.48040133 -0.66857665  2.25348861  3.26885604
#  -7.46732047  8.86117734 -6.94514655  6.18362126  2.36703297 -5.58387528
#   4.39818127 -8.35889526  2.01178985  6.86299796 -8.34373966  6.57197061
#  -4.60138878 -1.49475603  7.42138818 -5.58331134  1.75481752 -1.9030065
#   3.61138613 -5.90928478  6.70972512 -0.38222796 -0.10800072 -5.69215353
#   3.26362198  2.24595936 -2.12504482 -0.42821135  2.24309992]
# (array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#          -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#          -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#          -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#          -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#          -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#          -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#          -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#          -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#          -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#          -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#          -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#          -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#           0.50505051,   0.70707071,   0.90909091,   1.11111111,
#           1.31313131,   1.51515152,   1.71717172,   1.91919192,
#           2.12121212,   2.32323232,   2.52525253,   2.72727273,
#           2.92929293,   3.13131313,   3.33333333,   3.53535354,
#           3.73737374,   3.93939394,   4.14141414,   4.34343434,
#           4.54545455,   4.74747475,   4.94949495,   5.15151515,
#           5.35353535,   5.55555556,   5.75757576,   5.95959596,
#           6.16161616,   6.36363636,   6.56565657,   6.76767677,
#           6.96969697,   7.17171717,   7.37373737,   7.57575758,
#           7.77777778,   7.97979798,   8.18181818,   8.38383838,
#           8.58585859,   8.78787879,   8.98989899,   9.19191919,
#           9.39393939,   9.5959596 ,   9.7979798 ,  10.        ]),
#  array([ 2.20244658e+03,  1.83663881e+03,  1.53223304e+03,  1.27883936e+03,
#          1.06783735e+03,  8.92073061e+02,  7.45608200e+02,  6.23512365e+02,
#          5.21690979e+02,  4.36742737e+02,  3.65841489e+02,  3.06638354e+02,
#          2.57180582e+02,  2.15844288e+02,  1.81278669e+02,  1.52359744e+02,
#          1.28151974e+02,  1.07876415e+02,  9.08842976e+01,  7.66350786e+01,
#          6.46782314e+01,  5.46381157e+01,  4.62014094e+01,  3.91066665e+01,
#          3.31356375e+01,  2.81060532e+01,  2.38656239e+01,  2.02870475e+01,
#          1.72638558e+01,  1.47069563e+01,  1.25417536e+01,  1.07057507e+01,
#          9.14655055e+00,  7.82018967e+00,  6.68974815e+00,  5.72418964e+00,
#          4.89739229e+00,  4.18733886e+00,  3.57543882e+00,  3.04596043e+00,
#          2.58555397e+00,  2.18285069e+00,  1.82812434e+00,  1.51300449e+00,
#          1.23023229e+00,  9.73450947e-01,  7.37024309e-01,  5.15877724e-01,
#          3.05356285e-01,  1.01096014e-01, -1.01096014e-01, -3.05356285e-01,
#         -5.15877724e-01, -7.37024309e-01, -9.73450947e-01, -1.23023229e+00,
#         -1.51300449e+00, -1.82812434e+00, -2.18285069e+00, -2.58555397e+00,
#         -3.04596043e+00, -3.57543882e+00, -4.18733886e+00, -4.89739229e+00,
#         -5.72418964e+00, -6.68974815e+00, -7.82018967e+00, -9.14655055e+00,
#         -1.07057507e+01, -1.25417536e+01, -1.47069563e+01, -1.72638558e+01,
#         -2.02870475e+01, -2.38656239e+01, -2.81060532e+01, -3.31356375e+01,
#         -3.91066665e+01, -4.62014094e+01, -5.46381157e+01, -6.46782314e+01,
#         -7.66350786e+01, -9.08842976e+01, -1.07876415e+02, -1.28151974e+02,
#         -1.52359744e+02, -1.81278669e+02, -2.15844288e+02, -2.57180582e+02,
#         -3.06638354e+02, -3.65841489e+02, -4.36742737e+02, -5.21690979e+02,
#         -6.23512365e+02, -7.45608200e+02, -8.92073061e+02, -1.06783735e+03,
#         -1.27883936e+03, -1.53223304e+03, -1.83663881e+03, -2.20244658e+03]))

# %% [markdown]
# ## Данные для расчетов
# Модельные данные: ряд ARMA(4, 1)
# Реальные данные:
# - боковик USD-RUR 16.02.2022
# - растущий тренд USD-RUR 17.02.2022

# %%
# Генерируем и визуализируем ARMA(4,1)-ряд
import numpy as np
import random
import matplotlib.pyplot as plt

n_max = 120

a = [10., 8., 6., 2., .1]
d = [1., .6, .4, .1, .06]

p = [-1., 3., .1, -.8, .5]
p_const = a[0]*p[4] + a[1]*p[3] + a[2]*p[2] + a[3]*p[1] + a[4]*p[0]
print(p_const)

for i in range(5, n_max+5):
    p_next = a[0]*p[4] + a[1]*p[3] + a[2]*p[2] + a[3]*p[1] + a[4]*p[0] - .1*p[i-1]
    xi = np.random.normal(0., 10., 5)
    p_next += sum([d[i]*xi[i] for i in range(5)])
    p.append(p_next)
    
p_arr_arma = np.array(p[5:])
mu_arr_arma = np.diff(p_arr_arma)
# Сдвигаем разницу на одну единицу вперед (чтобы тренд был в конце интервала, а не в начале)
mu_arr_arma = np.append(0., mu_arr_arma)

n_lst = list(range(n_max))

figure = plt.figure(figsize=(8, 6))
plt.title("ARMA (4, 4) series") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("p_n") # ось ординат
plt.grid()      # включение отображение сетки
# plt.plot(p_ser)  # построение графика
plt.plot(n_lst, p_arr_arma, mu_arr_arma)
plt.legend(['p_n', 'mu'], loc="upper left")

plt.show()
# p_arr, mu_arr 


np.savetxt('p_arma-4-1.txt', p_arr_arma, fmt='%.18f')
np.savetxt('mu_arma-4-1.txt', mu_arr_arma, fmt='%.18f')
# Out:
# 5.1

# %%
col_names = ['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7']

df_stable = pd.read_csv('trades-16-02-22.csv', sep=';', names=col_names)
col3_ser_stable = df_stable['col3']
col3_ser_stable.reset_index(drop=True, inplace=True)

df_growth = pd.read_csv('trades-17-02-22.csv', sep=';', names=col_names)
col3_ser_growth = df_growth['col3']
col3_ser_growth.reset_index(drop=True, inplace=True)

df_si_14 = pd.read_csv('trades-si-14-02-22.csv', sep=';', names=col_names)
col3_ser_si_14 = df_si_14['col3']
col3_ser_si_14.reset_index(drop=True, inplace=True)

df_si_21 = pd.read_csv('trades-si-21-02-22.csv', sep=';', names=col_names)
col3_ser_si_21 = df_si_21['col3']
col3_ser_si_21.reset_index(drop=True, inplace=True)


price_series_stable = np.array(col3_ser_stable)
p_arr_stable = np.array([price_series_stable[i] for i in range(len(price_series_stable)) if i % 5000 == 0 ])
p_init_stable = price_series_stable[0]
mu_arr_stable = np.diff(p_arr_stable)
# Сдвигаем разницу на одну единицу вперед (чтобы тренд был в конце интервала, а не в начале)
mu_arr_stable = np.append(0., mu_arr_stable)

price_series_growth = np.array(col3_ser_growth)
p_arr_growth = np.array([price_series_growth[i] for i in range(len(price_series_growth)) if i % 5000 == 0 ])
p_init_growth = price_series_growth[0]
mu_arr_growth = np.diff(p_arr_growth)
mu_arr_growth = np.append(0., mu_arr_growth)

price_series_si_14 = np.array(col3_ser_si_14)
p_arr_si_14 = np.array([price_series_si_14[i] for i in range(len(price_series_si_14)) if i % 5000 == 0 ])
p_init_si_14 = price_series_si_14[0]
mu_arr_si_14 = np.diff(p_arr_si_14)
mu_arr_si_14 = np.append(0., mu_arr_si_14)

price_series_si_21 = np.array(col3_ser_si_21)
p_arr_si_21 = np.array([price_series_si_21[i] for i in range(len(price_series_si_21)) if i % 1000 == 0 ])
p_init_si_21 = price_series_si_21[0]
mu_arr_si_21 = np.diff(p_arr_si_21)
mu_arr_si_21 = np.append(0., mu_arr_si_21)


fig = plt.figure(figsize=(20, 10))
n_lst = list(range(len(p_arr_arma)))
plt.subplot(2, 5, 1)
plt.title("Price modeling by ARMA(4, 4) series") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("p_n") # ось ординат
plt.grid()      # включение отображение сетки
# plt.plot(p_ser)  # построение графика
plt.plot(n_lst, p_arr_arma)
plt.legend(['p_n'], loc="upper left")

plt.subplot(2, 5, 6)
plt.title("Trend modeling by first difference") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("mu") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(n_lst, mu_arr_arma, color='orange')
plt.legend(['mu'], loc="upper left")


n_lst = list(range(len(p_arr_stable)))
plt.subplot(2, 5, 2)
plt.title("Real data, price USD-RUB 16.02.2022") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("p_n") # ось ординат
plt.grid()      # включение отображение сетки
# plt.plot(p_ser)  # построение графика
plt.plot(n_lst, p_arr_stable)
plt.legend(['p_n'], loc="upper left")

plt.subplot(2, 5, 7)
plt.title("Trend modeling by first difference") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("mu") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(n_lst, mu_arr_stable, color='orange')
plt.legend(['mu'], loc="upper left")

n_lst = list(range(len(p_arr_growth)))
plt.subplot(2, 5, 3)
plt.title("Real data, price USD-RUB 17.02.2022") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("p_n") # ось ординат
plt.grid()      # включение отображение сетки
# plt.plot(p_ser)  # построение графика
plt.plot(n_lst, p_arr_growth)
plt.legend(['p_n'], loc="upper left")

plt.subplot(2, 5, 8)
plt.title("Trend modeling by first difference") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("mu") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(n_lst, mu_arr_growth, color='orange')
plt.legend(['mu'], loc="upper left")

n_lst = list(range(len(p_arr_si_14)))
plt.subplot(2, 5, 4)
plt.title("Real data, price USD-RUB 14.02.2022") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("p_n") # ось ординат
plt.grid()      # включение отображение сетки
# plt.plot(p_ser)  # построение графика
plt.plot(n_lst, p_arr_si_14)
plt.legend(['p_n'], loc="upper left")

plt.subplot(2, 5, 9)
plt.title("Trend modeling by first difference") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("mu") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(n_lst, mu_arr_si_14, color='orange')
plt.legend(['mu'], loc="upper left")

n_lst = list(range(len(p_arr_si_21)))
plt.subplot(255)
plt.title("Real data, price USD-RUB 21.02.2022") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("p_n") # ось ординат
plt.grid()      # включение отображение сетки
# plt.plot(p_ser)  # построение графика
plt.plot(n_lst, p_arr_si_21)
plt.legend(['p_n'], loc="upper left")

plt.subplot(2, 5, 10)
plt.title("Trend modeling by first difference") # заголовок
plt.xlabel("n") # ось абсцисс
plt.ylabel("mu") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(n_lst, mu_arr_si_21, color='orange')
plt.legend(['mu'], loc="upper left")




fig.subplots_adjust(hspace=.2)

plt.show()




# p_init = p_init_si_14
# p_arr = p_arr_si_14
# mu_arr = mu_arr_si_14




#p_init, p_arr, mu_arr

# %% [markdown]
# ## 16.02.2022 (боковик)

# %%
import alg
from math import fabs
import importlib

importlib.reload(alg)

# alg.calc_alg0(p_arr_stable, mu_arr_stable, 1.)
# alg.calc_alg2(p_arr_stable, mu_arr_stable, 1.)

p_arr_test = np.loadtxt('p_arma-4-1.txt')
mu_arr_test = np.loadtxt('mu_arma-4-1.txt')
# p_arr_test, mu_arr_test
alg.calc_alg0(p_arr_stable, mu_arr_stable, 1.)

p_arr_stable, mu_arr_stable
# Out:
# iter=1, t=1.0, p=75820, mu_n=-13.1 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=2, t=2.0, p=75794, mu_n=-2.6 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=3, t=3.0, p=75879, mu_n=8.5 mu_factor=0.65, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=4, t=4.0, p=75870, mu_n=-0.9 mu_factor=0.07, dI=1e-06, dg=0.0, K=10.0 -> Open long
# iter=5, t=5.0, p=75759, mu_n=-11.1 mu_factor=0.85, dI=-1e-06, dg=-111.0, K=-10.0 -> Close long
# iter=6, t=6.0, p=75788, mu_n=2.9 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=7, t=7.0, p=75820, mu_n=3.2 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=8, t=8.0, p=75818, mu_n=-0.2 mu_factor=0.02, dI=0.00111, dg=0.0, K=10.0 -> Open long
# iter=9, t=9.0, p=75775, mu_n=-4.3 mu_factor=0.33, dI=-0.00111, dg=-43.0, K=-10.0 -> Close long
# iter=10, t=10.0, p=75752, mu_n=-2.3 mu_factor=0.18, dI=0.00043, dg=0.0, K=10.0 -> Open long
# iter=11, t=11.0, p=75849, mu_n=9.7 mu_factor=0.74, dI=-0.00043, dg=97.0, K=-10.0 -> Close long
# iter=12, t=12.0, p=75826, mu_n=-2.3 mu_factor=0.18, dI=-0.00097, dg=0.0, K=-10.0 -> Open short
# iter=13, t=13.0, p=75788, mu_n=-3.8 mu_factor=0.29, dI=0.00097, dg=38.0, K=10.0 -> Close short
# iter=14, t=14.0, p=75665, mu_n=-12.3 mu_factor=0.94, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=15, t=15.0, p=75681, mu_n=1.6 mu_factor=0.12, dI=0.00038, dg=0.0, K=-10.0 -> Open short
# iter=16, t=16.0, p=75676, mu_n=-0.5 mu_factor=0.04, dI=-0.00038, dg=5.0, K=10.0 -> Close short
# iter=17, t=17.0, p=75597, mu_n=-7.9 mu_factor=0.6, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=18, t=18.0, p=75644, mu_n=4.7 mu_factor=0.36, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=19, t=19.0, p=75606, mu_n=-3.8 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=20, t=20.0, p=75591, mu_n=-1.5 mu_factor=0.11, dI=5e-05, dg=0.0, K=10.0 -> Open long
# iter=21, t=21.0, p=75535, mu_n=-5.6 mu_factor=0.43, dI=-5e-05, dg=-56.0, K=-10.0 -> Close long
# iter=22, t=22.0, p=75527, mu_n=-0.8 mu_factor=0.06, dI=0.00056, dg=0.0, K=10.0 -> Open long
# iter=23, t=23.0, p=75575, mu_n=4.8 mu_factor=0.37, dI=-0.00056, dg=48.0, K=-10.0 -> Close long
# iter=24, t=24.0, p=75572, mu_n=-0.3 mu_factor=0.02, dI=-0.00048, dg=0.0, K=-10.0 -> Open short
# iter=25, t=25.0, p=75615, mu_n=4.3 mu_factor=0.33, dI=0.00048, dg=-43.0, K=10.0 -> Close short
# iter=26, t=26.0, p=75610, mu_n=-0.5 mu_factor=0.04, dI=-0.00043, dg=0.0, K=-10.0 -> Open short
# iter=27, t=27.0, p=75639, mu_n=2.9 mu_factor=0.22, dI=0.00043, dg=-29.0, K=10.0 -> Close short
# iter=28, t=28.0, p=75681, mu_n=4.2 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=29, t=29.0, p=75631, mu_n=-5.0 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=30, t=30.0, p=75591, mu_n=-4.0 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=31, t=31.0, p=75610, mu_n=1.9 mu_factor=0.15, dI=-0.00029, dg=0.0, K=10.0 -> Open long
# iter=32, t=32.0, p=75570, mu_n=-4.0 mu_factor=0.31, dI=0.00029, dg=-40.0, K=-10.0 -> Close long
# iter=33, t=33.0, p=75531, mu_n=-3.9 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=34, t=34.0, p=75555, mu_n=2.4 mu_factor=0.18, dI=0.0004, dg=0.0, K=-10.0 -> Open short
# iter=35, t=35.0, p=75480, mu_n=-7.5 mu_factor=0.57, dI=-0.0004, dg=75.0, K=10.0 -> Close short
# iter=36, t=36.0, p=75551, mu_n=7.1 mu_factor=0.54, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=37, t=37.0, p=75544, mu_n=-0.7 mu_factor=0.05, dI=0.00075, dg=0.0, K=10.0 -> Open long
# iter=38, t=38.0, p=75553, mu_n=0.9 mu_factor=0.07, dI=-0.00075, dg=9.0, K=-10.0 -> Close long
# iter=39, t=39.0, p=75505, mu_n=-4.8 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=40, t=40.0, p=75493, mu_n=-1.2 mu_factor=0.09, dI=-9e-05, dg=0.0, K=-10.0 -> Open short
# iter=41, t=41.0, p=75490, mu_n=-0.3 mu_factor=0.02, dI=9e-05, dg=3.0, K=10.0 -> Close short
# iter=42, t=42.0, p=75552, mu_n=6.2 mu_factor=0.47, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=43, t=43.0, p=75534, mu_n=-1.8 mu_factor=0.14, dI=3e-05, dg=0.0, K=10.0 -> Open long
# iter=44, t=44.0, p=75636, mu_n=10.2 mu_factor=0.78, dI=-3e-05, dg=102.0, K=-10.0 -> Close long
# iter=45, t=45.0, p=75693, mu_n=5.7 mu_factor=0.44, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=46, t=46.0, p=75630, mu_n=-6.3 mu_factor=0.48, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=47, t=47.0, p=75720, mu_n=9.0 mu_factor=0.69, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=48, t=48.0, p=75713, mu_n=-0.7 mu_factor=0.05, dI=-0.00102, dg=0.0, K=-10.0 -> Open short
# iter=49, t=49.0, p=75776, mu_n=6.3 mu_factor=0.48, dI=0.00102, dg=-63.0, K=10.0 -> Close short
# iter=50, t=50.0, p=75768, mu_n=-0.8 mu_factor=0.06, dI=-0.00063, dg=0.0, K=-10.0 -> Open short
# iter=51, t=51.0, p=75733, mu_n=-3.5 mu_factor=0.27, dI=0.00063, dg=35.0, K=10.0 -> Close short
# iter=52, t=52.0, p=75671, mu_n=-6.2 mu_factor=0.47, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=53, t=53.0, p=75620, mu_n=-5.1 mu_factor=0.39, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=54, t=54.0, p=75712, mu_n=9.2 mu_factor=0.7, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=55, t=55.0, p=75633, mu_n=-7.9 mu_factor=0.6, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=56, t=56.0, p=75734, mu_n=10.1 mu_factor=0.77, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=57, t=57.0, p=75746, mu_n=1.2 mu_factor=0.09, dI=0.00035, dg=0.0, K=-10.0 -> Open short
# iter=58, t=58.0, p=75749, mu_n=0.3 mu_factor=0.02, dI=-0.00035, dg=-3.0, K=10.0 -> Close short
# iter=59, t=59.0, p=75752, mu_n=0.3 mu_factor=0.02, dI=-3e-05, dg=0.0, K=10.0 -> Open long
# iter=60, t=60.0, p=75667, mu_n=-8.5 mu_factor=0.65, dI=3e-05, dg=-85.0, K=-10.0 -> Close long
# iter=61, t=61.0, p=75688, mu_n=2.1 mu_factor=0.16, dI=0.00085, dg=0.0, K=-10.0 -> Open short
# iter=62, t=62.0, p=75659, mu_n=-2.9 mu_factor=0.22, dI=-0.00085, dg=29.0, K=10.0 -> Close short
# iter=63, t=63.0, p=75648, mu_n=-1.1 mu_factor=0.08, dI=0.00029, dg=0.0, K=10.0 -> Open long
# iter=64, t=64.0, p=75558, mu_n=-9.0 mu_factor=0.69, dI=-0.00029, dg=-90.0, K=-10.0 -> Close long
# iter=65, t=65.0, p=75550, mu_n=-0.8 mu_factor=0.06, dI=0.0009, dg=0.0, K=10.0 -> Open long
# iter=66, t=66.0, p=75586, mu_n=3.6 mu_factor=0.27, dI=-0.0009, dg=36.0, K=-10.0 -> Close long
# iter=67, t=67.0, p=75632, mu_n=4.6 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=68, t=68.0, p=75540, mu_n=-9.2 mu_factor=0.7, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=69, t=69.0, p=75496, mu_n=-4.4 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=70, t=70.0, p=75545, mu_n=4.9 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=71, t=71.0, p=75493, mu_n=-5.2 mu_factor=0.4, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=72, t=72.0, p=75485, mu_n=-0.8 mu_factor=0.06, dI=-0.00036, dg=0.0, K=-10.0 -> Open short
# iter=73, t=73.0, p=75417, mu_n=-6.8 mu_factor=0.52, dI=0.00036, dg=68.0, K=10.0 -> Close short
# iter=74, t=74.0, p=75418, mu_n=0.1 mu_factor=0.01, dI=0.00068, dg=0.0, K=-10.0 -> Open short
# iter=75, t=75.0, p=75474, mu_n=5.6 mu_factor=0.43, dI=-0.00068, dg=-56.0, K=10.0 -> Close short
# iter=76, t=76.0, p=75482, mu_n=0.8 mu_factor=0.06, dI=-0.00056, dg=0.0, K=10.0 -> Open long
# iter=77, t=77.0, p=75463, mu_n=-1.9 mu_factor=0.15, dI=0.00056, dg=-19.0, K=-10.0 -> Close long
# iter=78, t=78.0, p=75449, mu_n=-1.4 mu_factor=0.11, dI=0.00019, dg=0.0, K=10.0 -> Open long
# iter=79, t=79.0, p=75547, mu_n=9.8 mu_factor=0.75, dI=-0.00019, dg=98.0, K=-10.0 -> Close long
# iter=80, t=80.0, p=75543, mu_n=-0.4 mu_factor=0.03, dI=-0.00098, dg=0.0, K=-10.0 -> Open short
# iter=81, t=81.0, p=75576, mu_n=3.3 mu_factor=0.25, dI=0.00098, dg=-33.0, K=10.0 -> Close short
# iter=82, t=82.0, p=75576, mu_n=0.0 mu_factor=0.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=83, t=83.0, p=75612, mu_n=3.6 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=84, t=84.0, p=75608, mu_n=-0.4 mu_factor=0.03, dI=-0.00033, dg=0.0, K=-10.0 -> Open short
# iter=85, t=85.0, p=75621, mu_n=1.3 mu_factor=0.1, dI=0.00033, dg=-13.0, K=10.0 -> Close short
# iter=86, t=86.0, p=75588, mu_n=-3.3 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=87, t=87.0, p=75603, mu_n=1.5 mu_factor=0.11, dI=-0.00013, dg=0.0, K=10.0 -> Open long
# iter=88, t=88.0, p=75660, mu_n=5.7 mu_factor=0.44, dI=0.00013, dg=57.0, K=-10.0 -> Close long
# iter=89, t=89.0, p=75572, mu_n=-8.8 mu_factor=0.67, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=90, t=90.0, p=75671, mu_n=9.9 mu_factor=0.76, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=91, t=91.0, p=75782, mu_n=11.1 mu_factor=0.85, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=92, t=92.0, p=75797, mu_n=1.5 mu_factor=0.11, dI=-0.00057, dg=0.0, K=10.0 -> Open long
# iter=93, t=93.0, p=75787, mu_n=-1.0 mu_factor=0.08, dI=0.00057, dg=-10.0, K=-10.0 -> Close long
# iter=94, t=94.0, p=75764, mu_n=-2.3 mu_factor=0.18, dI=0.0001, dg=0.0, K=10.0 -> Open long
# iter=95, t=95.0, p=75862, mu_n=9.8 mu_factor=0.75, dI=-0.0001, dg=98.0, K=-10.0 -> Close long
# iter=96, t=96.0, p=75922, mu_n=6.0 mu_factor=0.46, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=97, t=97.0, p=75920, mu_n=-0.2 mu_factor=0.02, dI=-0.00098, dg=0.0, K=-10.0 -> Open short
# iter=98, t=98.0, p=75890, mu_n=-3.0 mu_factor=0.23, dI=0.00098, dg=30.0, K=10.0 -> Close short
# iter=99, t=99.0, p=75726, mu_n=-16.4 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=100, t=100.0, p=75825, mu_n=9.9 mu_factor=0.6, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=101, t=101.0, p=75853, mu_n=2.8 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=102, t=102.0, p=75875, mu_n=2.2 mu_factor=0.13, dI=0.0003, dg=0.0, K=-10.0 -> Open short
# iter=103, t=103.0, p=75816, mu_n=-5.9 mu_factor=0.36, dI=-0.0003, dg=59.0, K=10.0 -> Close short
# iter=104, t=104.0, p=75768, mu_n=-4.8 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=105, t=105.0, p=75783, mu_n=1.5 mu_factor=0.09, dI=0.00059, dg=0.0, K=-10.0 -> Open short
# iter=106, t=106.0, p=75786, mu_n=0.3 mu_factor=0.02, dI=-0.00059, dg=-3.0, K=10.0 -> Close short
# iter=107, t=107.0, p=75739, mu_n=-4.7 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=108, t=108.0, p=75849, mu_n=11.0 mu_factor=0.67, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=109, t=109.0, p=75757, mu_n=-9.2 mu_factor=0.56, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=110, t=110.0, p=75850, mu_n=9.3 mu_factor=0.57, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=111, t=111.0, p=75953, mu_n=10.3 mu_factor=0.63, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=112, t=112.0, p=75892, mu_n=-6.1 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=113, t=113.0, p=75889, mu_n=-0.3 mu_factor=0.02, dI=-3e-05, dg=0.0, K=-10.0 -> Open short
# iter=114, t=114.0, p=75793, mu_n=-9.6 mu_factor=0.59, dI=3e-05, dg=96.0, K=10.0 -> Close short
# iter=115, t=115.0, p=75784, mu_n=-0.9 mu_factor=0.05, dI=0.00096, dg=0.0, K=10.0 -> Open long
# iter=116, t=116.0, p=75844, mu_n=6.0 mu_factor=0.37, dI=-0.00096, dg=60.0, K=-10.0 -> Close long
# iter=117, t=117.0, p=75702, mu_n=-14.2 mu_factor=0.87, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=118, t=118.0, p=75702, mu_n=0.0 mu_factor=0.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=119, t=119.0, p=75633, mu_n=-6.9 mu_factor=0.42, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=120, t=120.0, p=75685, mu_n=5.2 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=121, t=121.0, p=75806, mu_n=12.1 mu_factor=0.74, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=122, t=122.0, p=75771, mu_n=-3.5 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=123, t=123.0, p=75786, mu_n=1.5 mu_factor=0.09, dI=-0.0006, dg=0.0, K=10.0 -> Open long
# iter=124, t=124.0, p=75819, mu_n=3.3 mu_factor=0.2, dI=0.0006, dg=33.0, K=-10.0 -> Close long
# iter=125, t=125.0, p=75770, mu_n=-4.9 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=126, t=126.0, p=75784, mu_n=1.4 mu_factor=0.09, dI=-0.00033, dg=0.0, K=10.0 -> Open long
# iter=127, t=127.0, p=75869, mu_n=8.5 mu_factor=0.52, dI=0.00033, dg=85.0, K=-10.0 -> Close long
# iter=128, t=128.0, p=75864, mu_n=-0.5 mu_factor=0.03, dI=-0.00085, dg=0.0, K=-10.0 -> Open short
# iter=129, t=129.0, p=75801, mu_n=-6.3 mu_factor=0.38, dI=0.00085, dg=63.0, K=10.0 -> Close short
# iter=130, t=130.0, p=75788, mu_n=-1.3 mu_factor=0.08, dI=0.00063, dg=0.0, K=10.0 -> Open long
# iter=131, t=131.0, p=75809, mu_n=2.1 mu_factor=0.13, dI=-0.00063, dg=21.0, K=-10.0 -> Close long
# iter=132, t=132.0, p=75818, mu_n=0.9 mu_factor=0.05, dI=-0.00021, dg=0.0, K=10.0 -> Open long
# iter=133, t=133.0, p=75654, mu_n=-16.4 mu_factor=1.0, dI=0.00021, dg=-164.0, K=-10.0 -> Close long
# Итоговая прибыль: -164.0
# (array([75951, 75820, 75794, 75879, 75870, 75759, 75788, 75820, 75818,
#         75775, 75752, 75849, 75826, 75788, 75665, 75681, 75676, 75597,
#         75644, 75606, 75591, 75535, 75527, 75575, 75572, 75615, 75610,
#         75639, 75681, 75631, 75591, 75610, 75570, 75531, 75555, 75480,
#         75551, 75544, 75553, 75505, 75493, 75490, 75552, 75534, 75636,
#         75693, 75630, 75720, 75713, 75776, 75768, 75733, 75671, 75620,
#         75712, 75633, 75734, 75746, 75749, 75752, 75667, 75688, 75659,
#         75648, 75558, 75550, 75586, 75632, 75540, 75496, 75545, 75493,
#         75485, 75417, 75418, 75474, 75482, 75463, 75449, 75547, 75543,
#         75576, 75576, 75612, 75608, 75621, 75588, 75603, 75660, 75572,
#         75671, 75782, 75797, 75787, 75764, 75862, 75922, 75920, 75890,
#         75726, 75825, 75853, 75875, 75816, 75768, 75783, 75786, 75739,
#         75849, 75757, 75850, 75953, 75892, 75889, 75793, 75784, 75844,
#         75702, 75702, 75633, 75685, 75806, 75771, 75786, 75819, 75770,
#         75784, 75869, 75864, 75801, 75788, 75809, 75818, 75654, 75744,
#         75825], dtype=int64),
#  array([   0., -131.,  -26.,   85.,   -9., -111.,   29.,   32.,   -2.,
#          -43.,  -23.,   97.,  -23.,  -38., -123.,   16.,   -5.,  -79.,
#           47.,  -38.,  -15.,  -56.,   -8.,   48.,   -3.,   43.,   -5.,
#           29.,   42.,  -50.,  -40.,   19.,  -40.,  -39.,   24.,  -75.,
#           71.,   -7.,    9.,  -48.,  -12.,   -3.,   62.,  -18.,  102.,
#           57.,  -63.,   90.,   -7.,   63.,   -8.,  -35.,  -62.,  -51.,
#           92.,  -79.,  101.,   12.,    3.,    3.,  -85.,   21.,  -29.,
#          -11.,  -90.,   -8.,   36.,   46.,  -92.,  -44.,   49.,  -52.,
#           -8.,  -68.,    1.,   56.,    8.,  -19.,  -14.,   98.,   -4.,
#           33.,    0.,   36.,   -4.,   13.,  -33.,   15.,   57.,  -88.,
#           99.,  111.,   15.,  -10.,  -23.,   98.,   60.,   -2.,  -30.,
#         -164.,   99.,   28.,   22.,  -59.,  -48.,   15.,    3.,  -47.,
#          110.,  -92.,   93.,  103.,  -61.,   -3.,  -96.,   -9.,   60.,
#         -142.,    0.,  -69.,   52.,  121.,  -35.,   15.,   33.,  -49.,
#           14.,   85.,   -5.,  -63.,  -13.,   21.,    9., -164.,   90.,
#           81.]))

# %%
importlib.reload(alg)

alg.calc_alg0(p_arr_stable, mu_arr_stable, 1.)
# Out:
# iter=1, t=1.0, p=75820, mu_n=-13.1 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=2, t=2.0, p=75794, mu_n=-2.6 mu_factor=0.2, dI=1e-06, dg=0.0, K=10.0 -> Open long
# iter=3, t=3.0, p=75879, mu_n=8.5 mu_factor=0.65, dI=-1e-06, dg=85.0, K=-10.0 -> Close long
# iter=4, t=4.0, p=75870, mu_n=-0.9 mu_factor=0.07, dI=-0.00085, dg=0.0, K=-10.0 -> Open short
# iter=5, t=5.0, p=75759, mu_n=-11.1 mu_factor=0.85, dI=0.00085, dg=111.0, K=10.0 -> Close short
# iter=6, t=6.0, p=75788, mu_n=2.9 mu_factor=0.22, dI=0.00111, dg=0.0, K=-10.0 -> Open short
# iter=7, t=7.0, p=75820, mu_n=3.2 mu_factor=0.24, dI=-0.00111, dg=-32.0, K=10.0 -> Close short
# iter=8, t=8.0, p=75818, mu_n=-0.2 mu_factor=0.02, dI=-0.00032, dg=0.0, K=-10.0 -> Open short
# iter=9, t=9.0, p=75775, mu_n=-4.3 mu_factor=0.33, dI=0.00032, dg=43.0, K=10.0 -> Close short
# iter=10, t=10.0, p=75752, mu_n=-2.3 mu_factor=0.18, dI=0.00043, dg=0.0, K=10.0 -> Open long
# iter=11, t=11.0, p=75849, mu_n=9.7 mu_factor=0.74, dI=-0.00043, dg=97.0, K=-10.0 -> Close long
# iter=12, t=12.0, p=75826, mu_n=-2.3 mu_factor=0.18, dI=-0.00097, dg=0.0, K=-10.0 -> Open short
# iter=13, t=13.0, p=75788, mu_n=-3.8 mu_factor=0.29, dI=0.00097, dg=38.0, K=10.0 -> Close short
# iter=14, t=14.0, p=75665, mu_n=-12.3 mu_factor=0.94, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=15, t=15.0, p=75681, mu_n=1.6 mu_factor=0.12, dI=0.00038, dg=0.0, K=-10.0 -> Open short
# iter=16, t=16.0, p=75676, mu_n=-0.5 mu_factor=0.04, dI=-0.00038, dg=5.0, K=10.0 -> Close short
# iter=17, t=17.0, p=75597, mu_n=-7.9 mu_factor=0.6, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=18, t=18.0, p=75644, mu_n=4.7 mu_factor=0.36, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=19, t=19.0, p=75606, mu_n=-3.8 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=20, t=20.0, p=75591, mu_n=-1.5 mu_factor=0.11, dI=5e-05, dg=0.0, K=10.0 -> Open long
# iter=21, t=21.0, p=75535, mu_n=-5.6 mu_factor=0.43, dI=-5e-05, dg=-56.0, K=-10.0 -> Close long
# iter=22, t=22.0, p=75527, mu_n=-0.8 mu_factor=0.06, dI=0.00056, dg=0.0, K=10.0 -> Open long
# iter=23, t=23.0, p=75575, mu_n=4.8 mu_factor=0.37, dI=-0.00056, dg=48.0, K=-10.0 -> Close long
# iter=24, t=24.0, p=75572, mu_n=-0.3 mu_factor=0.02, dI=-0.00048, dg=0.0, K=-10.0 -> Open short
# iter=25, t=25.0, p=75615, mu_n=4.3 mu_factor=0.33, dI=0.00048, dg=-43.0, K=10.0 -> Close short
# iter=26, t=26.0, p=75610, mu_n=-0.5 mu_factor=0.04, dI=-0.00043, dg=0.0, K=-10.0 -> Open short
# iter=27, t=27.0, p=75639, mu_n=2.9 mu_factor=0.22, dI=0.00043, dg=-29.0, K=10.0 -> Close short
# iter=28, t=28.0, p=75681, mu_n=4.2 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=29, t=29.0, p=75631, mu_n=-5.0 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=30, t=30.0, p=75591, mu_n=-4.0 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=31, t=31.0, p=75610, mu_n=1.9 mu_factor=0.15, dI=-0.00029, dg=0.0, K=10.0 -> Open long
# iter=32, t=32.0, p=75570, mu_n=-4.0 mu_factor=0.31, dI=0.00029, dg=-40.0, K=-10.0 -> Close long
# iter=33, t=33.0, p=75531, mu_n=-3.9 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=34, t=34.0, p=75555, mu_n=2.4 mu_factor=0.18, dI=0.0004, dg=0.0, K=-10.0 -> Open short
# iter=35, t=35.0, p=75480, mu_n=-7.5 mu_factor=0.57, dI=-0.0004, dg=75.0, K=10.0 -> Close short
# iter=36, t=36.0, p=75551, mu_n=7.1 mu_factor=0.54, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=37, t=37.0, p=75544, mu_n=-0.7 mu_factor=0.05, dI=0.00075, dg=0.0, K=10.0 -> Open long
# iter=38, t=38.0, p=75553, mu_n=0.9 mu_factor=0.07, dI=-0.00075, dg=9.0, K=-10.0 -> Close long
# iter=39, t=39.0, p=75505, mu_n=-4.8 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=40, t=40.0, p=75493, mu_n=-1.2 mu_factor=0.09, dI=-9e-05, dg=0.0, K=-10.0 -> Open short
# iter=41, t=41.0, p=75490, mu_n=-0.3 mu_factor=0.02, dI=9e-05, dg=3.0, K=10.0 -> Close short
# iter=42, t=42.0, p=75552, mu_n=6.2 mu_factor=0.47, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=43, t=43.0, p=75534, mu_n=-1.8 mu_factor=0.14, dI=3e-05, dg=0.0, K=10.0 -> Open long
# iter=44, t=44.0, p=75636, mu_n=10.2 mu_factor=0.78, dI=-3e-05, dg=102.0, K=-10.0 -> Close long
# iter=45, t=45.0, p=75693, mu_n=5.7 mu_factor=0.44, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=46, t=46.0, p=75630, mu_n=-6.3 mu_factor=0.48, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=47, t=47.0, p=75720, mu_n=9.0 mu_factor=0.69, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=48, t=48.0, p=75713, mu_n=-0.7 mu_factor=0.05, dI=-0.00102, dg=0.0, K=-10.0 -> Open short
# iter=49, t=49.0, p=75776, mu_n=6.3 mu_factor=0.48, dI=0.00102, dg=-63.0, K=10.0 -> Close short
# iter=50, t=50.0, p=75768, mu_n=-0.8 mu_factor=0.06, dI=-0.00063, dg=0.0, K=-10.0 -> Open short
# iter=51, t=51.0, p=75733, mu_n=-3.5 mu_factor=0.27, dI=0.00063, dg=35.0, K=10.0 -> Close short
# iter=52, t=52.0, p=75671, mu_n=-6.2 mu_factor=0.47, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=53, t=53.0, p=75620, mu_n=-5.1 mu_factor=0.39, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=54, t=54.0, p=75712, mu_n=9.2 mu_factor=0.7, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=55, t=55.0, p=75633, mu_n=-7.9 mu_factor=0.6, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=56, t=56.0, p=75734, mu_n=10.1 mu_factor=0.77, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=57, t=57.0, p=75746, mu_n=1.2 mu_factor=0.09, dI=0.00035, dg=0.0, K=-10.0 -> Open short
# iter=58, t=58.0, p=75749, mu_n=0.3 mu_factor=0.02, dI=-0.00035, dg=-3.0, K=10.0 -> Close short
# iter=59, t=59.0, p=75752, mu_n=0.3 mu_factor=0.02, dI=-3e-05, dg=0.0, K=10.0 -> Open long
# iter=60, t=60.0, p=75667, mu_n=-8.5 mu_factor=0.65, dI=3e-05, dg=-85.0, K=-10.0 -> Close long
# iter=61, t=61.0, p=75688, mu_n=2.1 mu_factor=0.16, dI=0.00085, dg=0.0, K=-10.0 -> Open short
# iter=62, t=62.0, p=75659, mu_n=-2.9 mu_factor=0.22, dI=-0.00085, dg=29.0, K=10.0 -> Close short
# iter=63, t=63.0, p=75648, mu_n=-1.1 mu_factor=0.08, dI=0.00029, dg=0.0, K=10.0 -> Open long
# iter=64, t=64.0, p=75558, mu_n=-9.0 mu_factor=0.69, dI=-0.00029, dg=-90.0, K=-10.0 -> Close long
# iter=65, t=65.0, p=75550, mu_n=-0.8 mu_factor=0.06, dI=0.0009, dg=0.0, K=10.0 -> Open long
# iter=66, t=66.0, p=75586, mu_n=3.6 mu_factor=0.27, dI=-0.0009, dg=36.0, K=-10.0 -> Close long
# iter=67, t=67.0, p=75632, mu_n=4.6 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=68, t=68.0, p=75540, mu_n=-9.2 mu_factor=0.7, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=69, t=69.0, p=75496, mu_n=-4.4 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=70, t=70.0, p=75545, mu_n=4.9 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=71, t=71.0, p=75493, mu_n=-5.2 mu_factor=0.4, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=72, t=72.0, p=75485, mu_n=-0.8 mu_factor=0.06, dI=-0.00036, dg=0.0, K=-10.0 -> Open short
# iter=73, t=73.0, p=75417, mu_n=-6.8 mu_factor=0.52, dI=0.00036, dg=68.0, K=10.0 -> Close short
# iter=74, t=74.0, p=75418, mu_n=0.1 mu_factor=0.01, dI=0.00068, dg=0.0, K=-10.0 -> Open short
# iter=75, t=75.0, p=75474, mu_n=5.6 mu_factor=0.43, dI=-0.00068, dg=-56.0, K=10.0 -> Close short
# iter=76, t=76.0, p=75482, mu_n=0.8 mu_factor=0.06, dI=-0.00056, dg=0.0, K=10.0 -> Open long
# iter=77, t=77.0, p=75463, mu_n=-1.9 mu_factor=0.15, dI=0.00056, dg=-19.0, K=-10.0 -> Close long
# iter=78, t=78.0, p=75449, mu_n=-1.4 mu_factor=0.11, dI=0.00019, dg=0.0, K=10.0 -> Open long
# iter=79, t=79.0, p=75547, mu_n=9.8 mu_factor=0.75, dI=-0.00019, dg=98.0, K=-10.0 -> Close long
# iter=80, t=80.0, p=75543, mu_n=-0.4 mu_factor=0.03, dI=-0.00098, dg=0.0, K=-10.0 -> Open short
# iter=81, t=81.0, p=75576, mu_n=3.3 mu_factor=0.25, dI=0.00098, dg=-33.0, K=10.0 -> Close short
# iter=82, t=82.0, p=75576, mu_n=0.0 mu_factor=0.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=83, t=83.0, p=75612, mu_n=3.6 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=84, t=84.0, p=75608, mu_n=-0.4 mu_factor=0.03, dI=-0.00033, dg=0.0, K=-10.0 -> Open short
# iter=85, t=85.0, p=75621, mu_n=1.3 mu_factor=0.1, dI=0.00033, dg=-13.0, K=10.0 -> Close short
# iter=86, t=86.0, p=75588, mu_n=-3.3 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=87, t=87.0, p=75603, mu_n=1.5 mu_factor=0.11, dI=-0.00013, dg=0.0, K=10.0 -> Open long
# iter=88, t=88.0, p=75660, mu_n=5.7 mu_factor=0.44, dI=0.00013, dg=57.0, K=-10.0 -> Close long
# iter=89, t=89.0, p=75572, mu_n=-8.8 mu_factor=0.67, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=90, t=90.0, p=75671, mu_n=9.9 mu_factor=0.76, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=91, t=91.0, p=75782, mu_n=11.1 mu_factor=0.85, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=92, t=92.0, p=75797, mu_n=1.5 mu_factor=0.11, dI=-0.00057, dg=0.0, K=10.0 -> Open long
# iter=93, t=93.0, p=75787, mu_n=-1.0 mu_factor=0.08, dI=0.00057, dg=-10.0, K=-10.0 -> Close long
# iter=94, t=94.0, p=75764, mu_n=-2.3 mu_factor=0.18, dI=0.0001, dg=0.0, K=10.0 -> Open long
# iter=95, t=95.0, p=75862, mu_n=9.8 mu_factor=0.75, dI=-0.0001, dg=98.0, K=-10.0 -> Close long
# iter=96, t=96.0, p=75922, mu_n=6.0 mu_factor=0.46, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=97, t=97.0, p=75920, mu_n=-0.2 mu_factor=0.02, dI=-0.00098, dg=0.0, K=-10.0 -> Open short
# iter=98, t=98.0, p=75890, mu_n=-3.0 mu_factor=0.23, dI=0.00098, dg=30.0, K=10.0 -> Close short
# iter=99, t=99.0, p=75726, mu_n=-16.4 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=100, t=100.0, p=75825, mu_n=9.9 mu_factor=0.6, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=101, t=101.0, p=75853, mu_n=2.8 mu_factor=0.17, dI=0.0003, dg=0.0, K=-10.0 -> Open short
# iter=102, t=102.0, p=75875, mu_n=2.2 mu_factor=0.13, dI=-0.0003, dg=-22.0, K=10.0 -> Close short
# iter=103, t=103.0, p=75816, mu_n=-5.9 mu_factor=0.36, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=104, t=104.0, p=75768, mu_n=-4.8 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=105, t=105.0, p=75783, mu_n=1.5 mu_factor=0.09, dI=-0.00022, dg=0.0, K=10.0 -> Open long
# iter=106, t=106.0, p=75786, mu_n=0.3 mu_factor=0.02, dI=0.00022, dg=3.0, K=-10.0 -> Close long
# iter=107, t=107.0, p=75739, mu_n=-4.7 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=108, t=108.0, p=75849, mu_n=11.0 mu_factor=0.67, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=109, t=109.0, p=75757, mu_n=-9.2 mu_factor=0.56, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=110, t=110.0, p=75850, mu_n=9.3 mu_factor=0.57, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=111, t=111.0, p=75953, mu_n=10.3 mu_factor=0.63, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=112, t=112.0, p=75892, mu_n=-6.1 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=113, t=113.0, p=75889, mu_n=-0.3 mu_factor=0.02, dI=-3e-05, dg=0.0, K=-10.0 -> Open short
# iter=114, t=114.0, p=75793, mu_n=-9.6 mu_factor=0.59, dI=3e-05, dg=96.0, K=10.0 -> Close short
# iter=115, t=115.0, p=75784, mu_n=-0.9 mu_factor=0.05, dI=0.00096, dg=0.0, K=10.0 -> Open long
# iter=116, t=116.0, p=75844, mu_n=6.0 mu_factor=0.37, dI=-0.00096, dg=60.0, K=-10.0 -> Close long
# iter=117, t=117.0, p=75702, mu_n=-14.2 mu_factor=0.87, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=118, t=118.0, p=75702, mu_n=0.0 mu_factor=0.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=119, t=119.0, p=75633, mu_n=-6.9 mu_factor=0.42, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=120, t=120.0, p=75685, mu_n=5.2 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=121, t=121.0, p=75806, mu_n=12.1 mu_factor=0.74, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=122, t=122.0, p=75771, mu_n=-3.5 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=123, t=123.0, p=75786, mu_n=1.5 mu_factor=0.09, dI=-0.0006, dg=0.0, K=10.0 -> Open long
# iter=124, t=124.0, p=75819, mu_n=3.3 mu_factor=0.2, dI=0.0006, dg=33.0, K=-10.0 -> Close long
# iter=125, t=125.0, p=75770, mu_n=-4.9 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=126, t=126.0, p=75784, mu_n=1.4 mu_factor=0.09, dI=-0.00033, dg=0.0, K=10.0 -> Open long
# iter=127, t=127.0, p=75869, mu_n=8.5 mu_factor=0.52, dI=0.00033, dg=85.0, K=-10.0 -> Close long
# iter=128, t=128.0, p=75864, mu_n=-0.5 mu_factor=0.03, dI=-0.00085, dg=0.0, K=-10.0 -> Open short
# iter=129, t=129.0, p=75801, mu_n=-6.3 mu_factor=0.38, dI=0.00085, dg=63.0, K=10.0 -> Close short
# iter=130, t=130.0, p=75788, mu_n=-1.3 mu_factor=0.08, dI=0.00063, dg=0.0, K=10.0 -> Open long
# iter=131, t=131.0, p=75809, mu_n=2.1 mu_factor=0.13, dI=-0.00063, dg=21.0, K=-10.0 -> Close long
# iter=132, t=132.0, p=75818, mu_n=0.9 mu_factor=0.05, dI=-0.00021, dg=0.0, K=10.0 -> Open long
# iter=133, t=133.0, p=75654, mu_n=-16.4 mu_factor=1.0, dI=0.00021, dg=-164.0, K=-10.0 -> Close long
# Итоговая прибыль: -164.0

# %% [markdown]
# ## 17.02.2022 (рост)

# %%
alg.calc_alg0(p_arr_growth, mu_arr_growth, 1.)
# Out:
# iter=1, t=1.0, p=76182, mu_n=34.1 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=2, t=2.0, p=76177, mu_n=-0.5 mu_factor=0.01, dI=1e-06, dg=0.0, K=10.0 -> Open long
# iter=3, t=3.0, p=76240, mu_n=6.3 mu_factor=0.18, dI=-1e-06, dg=63.0, K=-10.0 -> Close long
# iter=4, t=4.0, p=76234, mu_n=-0.6 mu_factor=0.02, dI=-0.00063, dg=0.0, K=-10.0 -> Open short
# iter=5, t=5.0, p=76301, mu_n=6.7 mu_factor=0.2, dI=0.00063, dg=-67.0, K=10.0 -> Close short
# iter=6, t=6.0, p=76295, mu_n=-0.6 mu_factor=0.02, dI=-0.00067, dg=0.0, K=-10.0 -> Open short
# iter=7, t=7.0, p=76232, mu_n=-6.3 mu_factor=0.18, dI=0.00067, dg=63.0, K=10.0 -> Close short
# iter=8, t=8.0, p=76266, mu_n=3.4 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=9, t=9.0, p=76290, mu_n=2.4 mu_factor=0.07, dI=0.00063, dg=0.0, K=-10.0 -> Open short
# iter=10, t=10.0, p=76141, mu_n=-14.9 mu_factor=0.44, dI=-0.00063, dg=149.0, K=10.0 -> Close short
# iter=11, t=11.0, p=76134, mu_n=-0.7 mu_factor=0.02, dI=0.00149, dg=0.0, K=10.0 -> Open long
# iter=12, t=12.0, p=76191, mu_n=5.7 mu_factor=0.17, dI=-0.00149, dg=57.0, K=-10.0 -> Close long
# iter=13, t=13.0, p=76129, mu_n=-6.2 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=14, t=14.0, p=76254, mu_n=12.5 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=15, t=15.0, p=76276, mu_n=2.2 mu_factor=0.06, dI=-0.00057, dg=0.0, K=10.0 -> Open long
# iter=16, t=16.0, p=76333, mu_n=5.7 mu_factor=0.17, dI=0.00057, dg=57.0, K=-10.0 -> Close long
# iter=17, t=17.0, p=76351, mu_n=1.8 mu_factor=0.05, dI=-0.00057, dg=0.0, K=10.0 -> Open long
# iter=18, t=18.0, p=76420, mu_n=6.9 mu_factor=0.2, dI=0.00057, dg=69.0, K=-10.0 -> Close long
# iter=19, t=19.0, p=76378, mu_n=-4.2 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=20, t=20.0, p=76266, mu_n=-11.2 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=21, t=21.0, p=76320, mu_n=5.4 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=22, t=22.0, p=76284, mu_n=-3.6 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=23, t=23.0, p=76314, mu_n=3.0 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=24, t=24.0, p=76245, mu_n=-6.9 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=25, t=25.0, p=76219, mu_n=-2.6 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=26, t=26.0, p=76206, mu_n=-1.3 mu_factor=0.04, dI=-0.00069, dg=0.0, K=-10.0 -> Open short
# iter=27, t=27.0, p=76133, mu_n=-7.3 mu_factor=0.21, dI=0.00069, dg=73.0, K=10.0 -> Close short
# iter=28, t=28.0, p=76176, mu_n=4.3 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=29, t=29.0, p=76211, mu_n=3.5 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=30, t=30.0, p=76055, mu_n=-15.6 mu_factor=0.46, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=31, t=31.0, p=76138, mu_n=8.3 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=32, t=32.0, p=76216, mu_n=7.8 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=33, t=33.0, p=76278, mu_n=6.2 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=34, t=34.0, p=76281, mu_n=0.3 mu_factor=0.01, dI=0.00073, dg=0.0, K=-10.0 -> Open short
# iter=35, t=35.0, p=76361, mu_n=8.0 mu_factor=0.23, dI=-0.00073, dg=-80.0, K=10.0 -> Close short
# iter=36, t=36.0, p=76366, mu_n=0.5 mu_factor=0.01, dI=-0.0008, dg=0.0, K=10.0 -> Open long
# iter=37, t=37.0, p=76329, mu_n=-3.7 mu_factor=0.11, dI=0.0008, dg=-37.0, K=-10.0 -> Close long
# iter=38, t=38.0, p=76343, mu_n=1.4 mu_factor=0.04, dI=0.00037, dg=0.0, K=-10.0 -> Open short
# iter=39, t=39.0, p=76297, mu_n=-4.6 mu_factor=0.13, dI=-0.00037, dg=46.0, K=10.0 -> Close short
# iter=40, t=40.0, p=76371, mu_n=7.4 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=41, t=41.0, p=76418, mu_n=4.7 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=42, t=42.0, p=76380, mu_n=-3.8 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=43, t=43.0, p=76378, mu_n=-0.2 mu_factor=0.01, dI=0.00046, dg=0.0, K=10.0 -> Open long
# iter=44, t=44.0, p=76308, mu_n=-7.0 mu_factor=0.21, dI=-0.00046, dg=-70.0, K=-10.0 -> Close long
# iter=45, t=45.0, p=76250, mu_n=-5.8 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=46, t=46.0, p=76224, mu_n=-2.6 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=47, t=47.0, p=76240, mu_n=1.6 mu_factor=0.05, dI=0.0007, dg=0.0, K=-10.0 -> Open short
# iter=48, t=48.0, p=76164, mu_n=-7.6 mu_factor=0.22, dI=-0.0007, dg=76.0, K=10.0 -> Close short
# iter=49, t=49.0, p=76312, mu_n=14.8 mu_factor=0.43, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=50, t=50.0, p=76443, mu_n=13.1 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=51, t=51.0, p=76499, mu_n=5.6 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=52, t=52.0, p=76526, mu_n=2.7 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=53, t=53.0, p=76530, mu_n=0.4 mu_factor=0.01, dI=0.00076, dg=0.0, K=-10.0 -> Open short
# iter=54, t=54.0, p=76594, mu_n=6.4 mu_factor=0.19, dI=-0.00076, dg=-64.0, K=10.0 -> Close short
# iter=55, t=55.0, p=76718, mu_n=12.4 mu_factor=0.36, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=56, t=56.0, p=76787, mu_n=6.9 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=57, t=57.0, p=76739, mu_n=-4.8 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=58, t=58.0, p=76653, mu_n=-8.6 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=59, t=59.0, p=76666, mu_n=1.3 mu_factor=0.04, dI=-0.00064, dg=0.0, K=10.0 -> Open long
# iter=60, t=60.0, p=76722, mu_n=5.6 mu_factor=0.16, dI=0.00064, dg=56.0, K=-10.0 -> Close long
# iter=61, t=61.0, p=76740, mu_n=1.8 mu_factor=0.05, dI=-0.00056, dg=0.0, K=10.0 -> Open long
# iter=62, t=62.0, p=76820, mu_n=8.0 mu_factor=0.23, dI=0.00056, dg=80.0, K=-10.0 -> Close long
# iter=63, t=63.0, p=76905, mu_n=8.5 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=64, t=64.0, p=76903, mu_n=-0.2 mu_factor=0.01, dI=-0.0008, dg=0.0, K=-10.0 -> Open short
# iter=65, t=65.0, p=76859, mu_n=-4.4 mu_factor=0.13, dI=0.0008, dg=44.0, K=10.0 -> Close short
# iter=66, t=66.0, p=76743, mu_n=-11.6 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=67, t=67.0, p=76813, mu_n=7.0 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=68, t=68.0, p=76872, mu_n=5.9 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=69, t=69.0, p=76926, mu_n=5.4 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=70, t=70.0, p=76988, mu_n=6.2 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=71, t=71.0, p=77067, mu_n=7.9 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=72, t=72.0, p=77166, mu_n=9.9 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=73, t=73.0, p=77171, mu_n=0.5 mu_factor=0.01, dI=0.00044, dg=0.0, K=-10.0 -> Open short
# iter=74, t=74.0, p=77024, mu_n=-14.7 mu_factor=0.43, dI=-0.00044, dg=147.0, K=10.0 -> Close short
# iter=75, t=75.0, p=76986, mu_n=-3.8 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=76, t=76.0, p=76968, mu_n=-1.8 mu_factor=0.05, dI=0.00147, dg=0.0, K=10.0 -> Open long
# iter=77, t=77.0, p=76943, mu_n=-2.5 mu_factor=0.07, dI=-0.00147, dg=-25.0, K=-10.0 -> Close long
# iter=78, t=78.0, p=76843, mu_n=-10.0 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=79, t=79.0, p=76872, mu_n=2.9 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=80, t=80.0, p=76826, mu_n=-4.6 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=81, t=81.0, p=76746, mu_n=-8.0 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=82, t=82.0, p=76824, mu_n=7.8 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=83, t=83.0, p=76829, mu_n=0.5 mu_factor=0.01, dI=0.00025, dg=0.0, K=-10.0 -> Open short
# iter=84, t=84.0, p=76836, mu_n=0.7 mu_factor=0.02, dI=-0.00025, dg=-7.0, K=10.0 -> Close short
# iter=85, t=85.0, p=76953, mu_n=11.7 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=86, t=86.0, p=76985, mu_n=3.2 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=87, t=87.0, p=76958, mu_n=-2.7 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=88, t=88.0, p=76924, mu_n=-3.4 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=89, t=89.0, p=76775, mu_n=-14.9 mu_factor=0.44, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=90, t=90.0, p=76773, mu_n=-0.2 mu_factor=0.01, dI=-7e-05, dg=0.0, K=-10.0 -> Open short
# iter=91, t=91.0, p=76709, mu_n=-6.4 mu_factor=0.19, dI=7e-05, dg=64.0, K=10.0 -> Close short
# iter=92, t=92.0, p=76764, mu_n=5.5 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=93, t=93.0, p=76634, mu_n=-13.0 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=94, t=94.0, p=76610, mu_n=-2.4 mu_factor=0.07, dI=0.00064, dg=0.0, K=10.0 -> Open long
# iter=95, t=95.0, p=76586, mu_n=-2.4 mu_factor=0.07, dI=-0.00064, dg=-24.0, K=-10.0 -> Close long
# iter=96, t=96.0, p=76594, mu_n=0.8 mu_factor=0.02, dI=0.00024, dg=0.0, K=-10.0 -> Open short
# iter=97, t=97.0, p=76570, mu_n=-2.4 mu_factor=0.07, dI=-0.00024, dg=24.0, K=10.0 -> Close short
# iter=98, t=98.0, p=76460, mu_n=-11.0 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=99, t=99.0, p=76530, mu_n=7.0 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=100, t=100.0, p=76503, mu_n=-2.7 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=101, t=101.0, p=76609, mu_n=10.6 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=102, t=102.0, p=76530, mu_n=-7.9 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=103, t=103.0, p=76464, mu_n=-6.6 mu_factor=0.19, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=104, t=104.0, p=76499, mu_n=3.5 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=105, t=105.0, p=76472, mu_n=-2.7 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=106, t=106.0, p=76432, mu_n=-4.0 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=107, t=107.0, p=76437, mu_n=0.5 mu_factor=0.01, dI=0.00024, dg=0.0, K=-10.0 -> Open short
# iter=108, t=108.0, p=76316, mu_n=-12.1 mu_factor=0.35, dI=-0.00024, dg=121.0, K=10.0 -> Close short
# iter=109, t=109.0, p=76344, mu_n=2.8 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=110, t=110.0, p=76349, mu_n=0.5 mu_factor=0.01, dI=0.00121, dg=0.0, K=-10.0 -> Open short
# iter=111, t=111.0, p=76416, mu_n=6.7 mu_factor=0.2, dI=-0.00121, dg=-67.0, K=10.0 -> Close short
# iter=112, t=112.0, p=76456, mu_n=4.0 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=113, t=113.0, p=76478, mu_n=2.2 mu_factor=0.06, dI=-0.00067, dg=0.0, K=10.0 -> Open long
# iter=114, t=114.0, p=76534, mu_n=5.6 mu_factor=0.16, dI=0.00067, dg=56.0, K=-10.0 -> Close long
# iter=115, t=115.0, p=76521, mu_n=-1.3 mu_factor=0.04, dI=-0.00056, dg=0.0, K=-10.0 -> Open short
# iter=116, t=116.0, p=76452, mu_n=-6.9 mu_factor=0.2, dI=0.00056, dg=69.0, K=10.0 -> Close short
# iter=117, t=117.0, p=76464, mu_n=1.2 mu_factor=0.04, dI=0.00069, dg=0.0, K=-10.0 -> Open short
# iter=118, t=118.0, p=76383, mu_n=-8.1 mu_factor=0.24, dI=-0.00069, dg=81.0, K=10.0 -> Close short
# iter=119, t=119.0, p=76485, mu_n=10.2 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=120, t=120.0, p=76520, mu_n=3.5 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=121, t=121.0, p=76415, mu_n=-10.5 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=122, t=122.0, p=76274, mu_n=-14.1 mu_factor=0.41, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=123, t=123.0, p=76215, mu_n=-5.9 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=124, t=124.0, p=76268, mu_n=5.3 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=125, t=125.0, p=76350, mu_n=8.2 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=126, t=126.0, p=76336, mu_n=-1.4 mu_factor=0.04, dI=0.00081, dg=0.0, K=10.0 -> Open long
# iter=127, t=127.0, p=76274, mu_n=-6.2 mu_factor=0.18, dI=-0.00081, dg=-62.0, K=-10.0 -> Close long
# iter=128, t=128.0, p=76180, mu_n=-9.4 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=129, t=129.0, p=76278, mu_n=9.8 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=130, t=130.0, p=76296, mu_n=1.8 mu_factor=0.05, dI=0.00062, dg=0.0, K=-10.0 -> Open short
# iter=131, t=131.0, p=76305, mu_n=0.9 mu_factor=0.03, dI=-0.00062, dg=-9.0, K=10.0 -> Close short
# iter=132, t=132.0, p=76219, mu_n=-8.6 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=133, t=133.0, p=76203, mu_n=-1.6 mu_factor=0.05, dI=-9e-05, dg=0.0, K=-10.0 -> Open short
# iter=134, t=134.0, p=76152, mu_n=-5.1 mu_factor=0.15, dI=9e-05, dg=51.0, K=10.0 -> Close short
# iter=135, t=135.0, p=76264, mu_n=11.2 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=136, t=136.0, p=76218, mu_n=-4.6 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=137, t=137.0, p=76495, mu_n=27.7 mu_factor=0.81, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=138, t=138.0, p=76341, mu_n=-15.4 mu_factor=0.45, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=139, t=139.0, p=76449, mu_n=10.8 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=140, t=140.0, p=76444, mu_n=-0.5 mu_factor=0.01, dI=0.00051, dg=0.0, K=10.0 -> Open long
# iter=141, t=141.0, p=76454, mu_n=1.0 mu_factor=0.03, dI=-0.00051, dg=10.0, K=-10.0 -> Close long
# iter=142, t=142.0, p=76538, mu_n=8.4 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=143, t=143.0, p=76596, mu_n=5.8 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=144, t=144.0, p=76680, mu_n=8.4 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=145, t=145.0, p=76604, mu_n=-7.6 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=146, t=146.0, p=76531, mu_n=-7.3 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=147, t=147.0, p=76430, mu_n=-10.1 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=148, t=148.0, p=76462, mu_n=3.2 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=149, t=149.0, p=76502, mu_n=4.0 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=150, t=150.0, p=76664, mu_n=16.2 mu_factor=0.48, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=151, t=151.0, p=76685, mu_n=2.1 mu_factor=0.06, dI=-0.0001, dg=0.0, K=10.0 -> Open long
# iter=152, t=152.0, p=76680, mu_n=-0.5 mu_factor=0.01, dI=0.0001, dg=-5.0, K=-10.0 -> Close long
# iter=153, t=153.0, p=76772, mu_n=9.2 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=154, t=154.0, p=76740, mu_n=-3.2 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=155, t=155.0, p=76707, mu_n=-3.3 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=156, t=156.0, p=76812, mu_n=10.5 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=157, t=157.0, p=76892, mu_n=8.0 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=158, t=158.0, p=76902, mu_n=1.0 mu_factor=0.03, dI=5e-05, dg=0.0, K=-10.0 -> Open short
# iter=159, t=159.0, p=76812, mu_n=-9.0 mu_factor=0.26, dI=-5e-05, dg=90.0, K=10.0 -> Close short
# iter=160, t=160.0, p=76722, mu_n=-9.0 mu_factor=0.26, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=161, t=161.0, p=76770, mu_n=4.8 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=162, t=162.0, p=76671, mu_n=-9.9 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=163, t=163.0, p=76694, mu_n=2.3 mu_factor=0.07, dI=0.0009, dg=0.0, K=-10.0 -> Open short
# iter=164, t=164.0, p=76674, mu_n=-2.0 mu_factor=0.06, dI=-0.0009, dg=20.0, K=10.0 -> Close short
# iter=165, t=165.0, p=76593, mu_n=-8.1 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=166, t=166.0, p=76519, mu_n=-7.4 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=167, t=167.0, p=76572, mu_n=5.3 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=168, t=168.0, p=76595, mu_n=2.3 mu_factor=0.07, dI=0.0002, dg=0.0, K=-10.0 -> Open short
# iter=169, t=169.0, p=76622, mu_n=2.7 mu_factor=0.08, dI=-0.0002, dg=-27.0, K=10.0 -> Close short
# iter=170, t=170.0, p=76623, mu_n=0.1 mu_factor=0.0, dI=-0.00027, dg=0.0, K=10.0 -> Open long
# iter=171, t=171.0, p=76623, mu_n=0.0 mu_factor=0.0, dI=0.00027, dg=0.0, K=-10.0 -> Close long
# iter=172, t=172.0, p=76589, mu_n=-3.4 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=173, t=173.0, p=76650, mu_n=6.1 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=174, t=174.0, p=76674, mu_n=2.4 mu_factor=0.07, dI=-0.0, dg=0.0, K=-10.0 -> Open short
# iter=175, t=175.0, p=76744, mu_n=7.0 mu_factor=0.21, dI=0.0, dg=-70.0, K=10.0 -> Close short
# iter=176, t=176.0, p=76807, mu_n=6.3 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=177, t=177.0, p=76881, mu_n=7.4 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=178, t=178.0, p=76830, mu_n=-5.1 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=179, t=179.0, p=76936, mu_n=10.6 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=180, t=180.0, p=76946, mu_n=1.0 mu_factor=0.03, dI=-0.0007, dg=0.0, K=10.0 -> Open long
# iter=181, t=181.0, p=76922, mu_n=-2.4 mu_factor=0.07, dI=0.0007, dg=-24.0, K=-10.0 -> Close long
# iter=182, t=182.0, p=76881, mu_n=-4.1 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=183, t=183.0, p=76783, mu_n=-9.8 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=184, t=184.0, p=76773, mu_n=-1.0 mu_factor=0.03, dI=0.00024, dg=0.0, K=10.0 -> Open long
# iter=185, t=185.0, p=76755, mu_n=-1.8 mu_factor=0.05, dI=-0.00024, dg=-18.0, K=-10.0 -> Close long
# iter=186, t=186.0, p=76730, mu_n=-2.5 mu_factor=0.07, dI=0.00018, dg=0.0, K=10.0 -> Open long
# iter=187, t=187.0, p=76748, mu_n=1.8 mu_factor=0.05, dI=-0.00018, dg=18.0, K=-10.0 -> Close long
# iter=188, t=188.0, p=76781, mu_n=3.3 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=189, t=189.0, p=76892, mu_n=11.1 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=190, t=190.0, p=76800, mu_n=-9.2 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=191, t=191.0, p=76838, mu_n=3.8 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=192, t=192.0, p=76836, mu_n=-0.2 mu_factor=0.01, dI=-0.00018, dg=0.0, K=-10.0 -> Open short
# iter=193, t=193.0, p=76789, mu_n=-4.7 mu_factor=0.14, dI=0.00018, dg=47.0, K=10.0 -> Close short
# iter=194, t=194.0, p=76857, mu_n=6.8 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=195, t=195.0, p=76835, mu_n=-2.2 mu_factor=0.06, dI=0.00047, dg=0.0, K=10.0 -> Open long
# iter=196, t=196.0, p=76765, mu_n=-7.0 mu_factor=0.21, dI=-0.00047, dg=-70.0, K=-10.0 -> Close long
# iter=197, t=197.0, p=76730, mu_n=-3.5 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=198, t=198.0, p=76739, mu_n=0.9 mu_factor=0.03, dI=0.0007, dg=0.0, K=-10.0 -> Open short
# iter=199, t=199.0, p=76670, mu_n=-6.9 mu_factor=0.2, dI=-0.0007, dg=69.0, K=10.0 -> Close short
# iter=200, t=200.0, p=76798, mu_n=12.8 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=201, t=201.0, p=76838, mu_n=4.0 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=202, t=202.0, p=76842, mu_n=0.4 mu_factor=0.01, dI=0.00069, dg=0.0, K=-10.0 -> Open short
# iter=203, t=203.0, p=76837, mu_n=-0.5 mu_factor=0.01, dI=-0.00069, dg=5.0, K=10.0 -> Close short
# iter=204, t=204.0, p=76912, mu_n=7.5 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=205, t=205.0, p=76945, mu_n=3.3 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# Итоговая прибыль: 0.0

# %%
alg.calc_alg0(p_arr_growth, mu_arr_growth, 1.)
# Out:
# iter=1, t=1.0, p=76182, mu_n=34.1 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=2, t=2.0, p=76177, mu_n=-0.5 mu_factor=0.01, dI=1e-06, dg=0.0, K=10.0 -> Open long
# iter=3, t=3.0, p=76240, mu_n=6.3 mu_factor=0.18, dI=-1e-06, dg=63.0, K=-10.0 -> Close long
# iter=4, t=4.0, p=76234, mu_n=-0.6 mu_factor=0.02, dI=-0.00011639296187683286, dg=0.0, K=-10.0 -> Open short
# iter=5, t=5.0, p=76301, mu_n=6.7 mu_factor=0.2, dI=0.00011639296187683286, dg=-67.0, K=10.0 -> Close short
# iter=6, t=6.0, p=76295, mu_n=-0.6 mu_factor=0.02, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=7, t=7.0, p=76232, mu_n=-6.3 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=8, t=8.0, p=76266, mu_n=3.4 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=9, t=9.0, p=76290, mu_n=2.4 mu_factor=0.07, dI=-0.00013164222873900296, dg=0.0, K=10.0 -> Open long
# iter=10, t=10.0, p=76141, mu_n=-14.9 mu_factor=0.44, dI=0.00013164222873900296, dg=-149.0, K=-10.0 -> Close long
# iter=11, t=11.0, p=76134, mu_n=-0.7 mu_factor=0.02, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=12, t=12.0, p=76191, mu_n=5.7 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=13, t=13.0, p=76129, mu_n=-6.2 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=14, t=14.0, p=76254, mu_n=12.5 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=15, t=15.0, p=76276, mu_n=2.2 mu_factor=0.06, dI=0.0006510557184750733, dg=0.0, K=-10.0 -> Open short
# iter=16, t=16.0, p=76333, mu_n=5.7 mu_factor=0.17, dI=-0.0006510557184750733, dg=-57.0, K=10.0 -> Close short
# iter=17, t=17.0, p=76351, mu_n=1.8 mu_factor=0.05, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=18, t=18.0, p=76420, mu_n=6.9 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=19, t=19.0, p=76378, mu_n=-4.2 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=20, t=20.0, p=76266, mu_n=-11.2 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=21, t=21.0, p=76320, mu_n=5.4 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=22, t=22.0, p=76284, mu_n=-3.6 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=23, t=23.0, p=76314, mu_n=3.0 mu_factor=0.09, dI=-9.527859237536655e-05, dg=0.0, K=10.0 -> Open long
# iter=24, t=24.0, p=76245, mu_n=-6.9 mu_factor=0.2, dI=9.527859237536655e-05, dg=-69.0, K=-10.0 -> Close long
# iter=25, t=25.0, p=76219, mu_n=-2.6 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=26, t=26.0, p=76206, mu_n=-1.3 mu_factor=0.04, dI=0.00013961876832844575, dg=0.0, K=10.0 -> Open long
# iter=27, t=27.0, p=76133, mu_n=-7.3 mu_factor=0.21, dI=-0.00013961876832844575, dg=-73.0, K=-10.0 -> Close long
# iter=28, t=28.0, p=76176, mu_n=4.3 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=29, t=29.0, p=76211, mu_n=3.5 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=30, t=30.0, p=76055, mu_n=-15.6 mu_factor=0.46, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=31, t=31.0, p=76138, mu_n=8.3 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=32, t=32.0, p=76216, mu_n=7.8 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=33, t=33.0, p=76278, mu_n=6.2 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=34, t=34.0, p=76281, mu_n=0.3 mu_factor=0.01, dI=0.0001562756598240469, dg=0.0, K=-10.0 -> Open short
# iter=35, t=35.0, p=76361, mu_n=8.0 mu_factor=0.23, dI=-0.0001562756598240469, dg=-80.0, K=10.0 -> Close short
# iter=36, t=36.0, p=76366, mu_n=0.5 mu_factor=0.01, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=37, t=37.0, p=76329, mu_n=-3.7 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=38, t=38.0, p=76343, mu_n=1.4 mu_factor=0.04, dI=-0.000187683284457478, dg=0.0, K=10.0 -> Open long
# iter=39, t=39.0, p=76297, mu_n=-4.6 mu_factor=0.13, dI=0.000187683284457478, dg=-46.0, K=-10.0 -> Close long
# iter=40, t=40.0, p=76371, mu_n=7.4 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=41, t=41.0, p=76418, mu_n=4.7 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=42, t=42.0, p=76380, mu_n=-3.8 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=43, t=43.0, p=76378, mu_n=-0.2 mu_factor=0.01, dI=6.205278592375366e-05, dg=0.0, K=10.0 -> Open long
# iter=44, t=44.0, p=76308, mu_n=-7.0 mu_factor=0.21, dI=-6.205278592375366e-05, dg=-70.0, K=-10.0 -> Close long
# iter=45, t=45.0, p=76250, mu_n=-5.8 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=46, t=46.0, p=76224, mu_n=-2.6 mu_factor=0.08, dI=0.0001436950146627566, dg=0.0, K=10.0 -> Open long
# iter=47, t=47.0, p=76240, mu_n=1.6 mu_factor=0.05, dI=-0.0001436950146627566, dg=16.0, K=-10.0 -> Close long
# iter=48, t=48.0, p=76164, mu_n=-7.6 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=49, t=49.0, p=76312, mu_n=14.8 mu_factor=0.43, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=50, t=50.0, p=76443, mu_n=13.1 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=51, t=51.0, p=76499, mu_n=5.6 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=52, t=52.0, p=76526, mu_n=2.7 mu_factor=0.08, dI=-7.507331378299121e-06, dg=0.0, K=10.0 -> Open long
# iter=53, t=53.0, p=76530, mu_n=0.4 mu_factor=0.01, dI=7.507331378299121e-06, dg=4.0, K=-10.0 -> Close long
# iter=54, t=54.0, p=76594, mu_n=6.4 mu_factor=0.19, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=55, t=55.0, p=76718, mu_n=12.4 mu_factor=0.36, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=56, t=56.0, p=76787, mu_n=6.9 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=57, t=57.0, p=76739, mu_n=-4.8 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=58, t=58.0, p=76653, mu_n=-8.6 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=59, t=59.0, p=76666, mu_n=1.3 mu_factor=0.04, dI=-4.6920821114369504e-07, dg=0.0, K=10.0 -> Open long
# iter=60, t=60.0, p=76722, mu_n=5.6 mu_factor=0.16, dI=4.6920821114369504e-07, dg=56.0, K=-10.0 -> Close long
# iter=61, t=61.0, p=76740, mu_n=1.8 mu_factor=0.05, dI=-9.196480938416421e-05, dg=0.0, K=10.0 -> Open long
# iter=62, t=62.0, p=76820, mu_n=8.0 mu_factor=0.23, dI=9.196480938416421e-05, dg=80.0, K=-10.0 -> Close long
# iter=63, t=63.0, p=76905, mu_n=8.5 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=64, t=64.0, p=76903, mu_n=-0.2 mu_factor=0.01, dI=-0.000187683284457478, dg=0.0, K=-10.0 -> Open short
# iter=65, t=65.0, p=76859, mu_n=-4.4 mu_factor=0.13, dI=0.000187683284457478, dg=44.0, K=10.0 -> Close short
# iter=66, t=66.0, p=76743, mu_n=-11.6 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=67, t=67.0, p=76813, mu_n=7.0 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=68, t=68.0, p=76872, mu_n=5.9 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=69, t=69.0, p=76926, mu_n=5.4 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=70, t=70.0, p=76988, mu_n=6.2 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=71, t=71.0, p=77067, mu_n=7.9 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=72, t=72.0, p=77166, mu_n=9.9 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=73, t=73.0, p=77171, mu_n=0.5 mu_factor=0.01, dI=5.67741935483871e-05, dg=0.0, K=-10.0 -> Open short
# iter=74, t=74.0, p=77024, mu_n=-14.7 mu_factor=0.43, dI=-5.67741935483871e-05, dg=147.0, K=10.0 -> Close short
# iter=75, t=75.0, p=76986, mu_n=-3.8 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=76, t=76.0, p=76968, mu_n=-1.8 mu_factor=0.05, dI=0.0006336950146627566, dg=0.0, K=10.0 -> Open long
# iter=77, t=77.0, p=76943, mu_n=-2.5 mu_factor=0.07, dI=-0.0006336950146627566, dg=-25.0, K=-10.0 -> Close long
# iter=78, t=78.0, p=76843, mu_n=-10.0 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=79, t=79.0, p=76872, mu_n=2.9 mu_factor=0.09, dI=1.8328445747800586e-05, dg=0.0, K=-10.0 -> Open short
# iter=80, t=80.0, p=76826, mu_n=-4.6 mu_factor=0.13, dI=-1.8328445747800586e-05, dg=46.0, K=10.0 -> Close short
# iter=81, t=81.0, p=76746, mu_n=-8.0 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=82, t=82.0, p=76824, mu_n=7.8 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=83, t=83.0, p=76829, mu_n=0.5 mu_factor=0.01, dI=6.205278592375366e-05, dg=0.0, K=-10.0 -> Open short
# iter=84, t=84.0, p=76836, mu_n=0.7 mu_factor=0.02, dI=-6.205278592375366e-05, dg=-7.0, K=10.0 -> Close short
# iter=85, t=85.0, p=76953, mu_n=11.7 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=86, t=86.0, p=76985, mu_n=3.2 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=87, t=87.0, p=76958, mu_n=-2.7 mu_factor=0.08, dI=-1.4369501466275658e-06, dg=0.0, K=-10.0 -> Open short
# iter=88, t=88.0, p=76924, mu_n=-3.4 mu_factor=0.1, dI=1.4369501466275658e-06, dg=34.0, K=10.0 -> Close short
# iter=89, t=89.0, p=76775, mu_n=-14.9 mu_factor=0.44, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=90, t=90.0, p=76773, mu_n=-0.2 mu_factor=0.01, dI=3.390029325513196e-05, dg=0.0, K=10.0 -> Open long
# iter=91, t=91.0, p=76709, mu_n=-6.4 mu_factor=0.19, dI=-3.390029325513196e-05, dg=-64.0, K=-10.0 -> Close long
# iter=92, t=92.0, p=76764, mu_n=5.5 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=93, t=93.0, p=76634, mu_n=-13.0 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=94, t=94.0, p=76610, mu_n=-2.4 mu_factor=0.07, dI=0.00012011730205278593, dg=0.0, K=10.0 -> Open long
# iter=95, t=95.0, p=76586, mu_n=-2.4 mu_factor=0.07, dI=-0.00012011730205278593, dg=-24.0, K=-10.0 -> Close long
# iter=96, t=96.0, p=76594, mu_n=0.8 mu_factor=0.02, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=97, t=97.0, p=76570, mu_n=-2.4 mu_factor=0.07, dI=1.689149560117302e-05, dg=0.0, K=10.0 -> Open long
# iter=98, t=98.0, p=76460, mu_n=-11.0 mu_factor=0.32, dI=-1.689149560117302e-05, dg=-110.0, K=-10.0 -> Close long
# iter=99, t=99.0, p=76530, mu_n=7.0 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=100, t=100.0, p=76503, mu_n=-2.7 mu_factor=0.08, dI=0.0003548387096774193, dg=0.0, K=10.0 -> Open long
# iter=101, t=101.0, p=76609, mu_n=10.6 mu_factor=0.31, dI=-0.0003548387096774193, dg=106.0, K=-10.0 -> Close long
# iter=102, t=102.0, p=76530, mu_n=-7.9 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=103, t=103.0, p=76464, mu_n=-6.6 mu_factor=0.19, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=104, t=104.0, p=76499, mu_n=3.5 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=105, t=105.0, p=76472, mu_n=-2.7 mu_factor=0.08, dI=-0.00032950146627565985, dg=0.0, K=-10.0 -> Open short
# iter=106, t=106.0, p=76432, mu_n=-4.0 mu_factor=0.12, dI=0.00032950146627565985, dg=40.0, K=10.0 -> Close short
# iter=107, t=107.0, p=76437, mu_n=0.5 mu_factor=0.01, dI=4.69208211143695e-05, dg=0.0, K=-10.0 -> Open short
# iter=108, t=108.0, p=76316, mu_n=-12.1 mu_factor=0.35, dI=-4.69208211143695e-05, dg=121.0, K=10.0 -> Close short
# iter=109, t=109.0, p=76344, mu_n=2.8 mu_factor=0.08, dI=0.0004293548387096775, dg=0.0, K=-10.0 -> Open short
# iter=110, t=110.0, p=76349, mu_n=0.5 mu_factor=0.01, dI=-0.0004293548387096775, dg=-5.0, K=10.0 -> Close short
# iter=111, t=111.0, p=76416, mu_n=6.7 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=112, t=112.0, p=76456, mu_n=4.0 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=113, t=113.0, p=76478, mu_n=2.2 mu_factor=0.06, dI=-7.331378299120235e-07, dg=0.0, K=10.0 -> Open long
# iter=114, t=114.0, p=76534, mu_n=5.6 mu_factor=0.16, dI=7.331378299120235e-07, dg=56.0, K=-10.0 -> Close long
# iter=115, t=115.0, p=76521, mu_n=-1.3 mu_factor=0.04, dI=-9.196480938416421e-05, dg=0.0, K=-10.0 -> Open short
# iter=116, t=116.0, p=76452, mu_n=-6.9 mu_factor=0.2, dI=9.196480938416421e-05, dg=69.0, K=10.0 -> Close short
# iter=117, t=117.0, p=76464, mu_n=1.2 mu_factor=0.04, dI=0.00013961876832844575, dg=0.0, K=-10.0 -> Open short
# iter=118, t=118.0, p=76383, mu_n=-8.1 mu_factor=0.24, dI=-0.00013961876832844575, dg=81.0, K=10.0 -> Close short
# iter=119, t=119.0, p=76485, mu_n=10.2 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=120, t=120.0, p=76520, mu_n=3.5 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=121, t=121.0, p=76415, mu_n=-10.5 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=122, t=122.0, p=76274, mu_n=-14.1 mu_factor=0.41, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=123, t=123.0, p=76215, mu_n=-5.9 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=124, t=124.0, p=76268, mu_n=5.3 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=125, t=125.0, p=76350, mu_n=8.2 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=126, t=126.0, p=76336, mu_n=-1.4 mu_factor=0.04, dI=0.00019240469208211145, dg=0.0, K=10.0 -> Open long
# iter=127, t=127.0, p=76274, mu_n=-6.2 mu_factor=0.18, dI=-0.00019240469208211145, dg=-62.0, K=-10.0 -> Close long
# iter=128, t=128.0, p=76180, mu_n=-9.4 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=129, t=129.0, p=76278, mu_n=9.8 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=130, t=130.0, p=76296, mu_n=1.8 mu_factor=0.05, dI=0.00011272727272727274, dg=0.0, K=-10.0 -> Open short
# iter=131, t=131.0, p=76305, mu_n=0.9 mu_factor=0.03, dI=-0.00011272727272727274, dg=-9.0, K=10.0 -> Close short
# iter=132, t=132.0, p=76219, mu_n=-8.6 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=133, t=133.0, p=76203, mu_n=-1.6 mu_factor=0.05, dI=-2.3753665689149557e-06, dg=0.0, K=-10.0 -> Open short
# iter=134, t=134.0, p=76152, mu_n=-5.1 mu_factor=0.15, dI=2.3753665689149557e-06, dg=51.0, K=10.0 -> Close short
# iter=135, t=135.0, p=76264, mu_n=11.2 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=136, t=136.0, p=76218, mu_n=-4.6 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=137, t=137.0, p=76495, mu_n=27.7 mu_factor=0.81, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=138, t=138.0, p=76341, mu_n=-15.4 mu_factor=0.45, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=139, t=139.0, p=76449, mu_n=10.8 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=140, t=140.0, p=76444, mu_n=-0.5 mu_factor=0.01, dI=7.627565982404692e-05, dg=0.0, K=10.0 -> Open long
# iter=141, t=141.0, p=76454, mu_n=1.0 mu_factor=0.03, dI=-7.627565982404692e-05, dg=10.0, K=-10.0 -> Close long
# iter=142, t=142.0, p=76538, mu_n=8.4 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=143, t=143.0, p=76596, mu_n=5.8 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=144, t=144.0, p=76680, mu_n=8.4 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=145, t=145.0, p=76604, mu_n=-7.6 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=146, t=146.0, p=76531, mu_n=-7.3 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=147, t=147.0, p=76430, mu_n=-10.1 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=148, t=148.0, p=76462, mu_n=3.2 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=149, t=149.0, p=76502, mu_n=4.0 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=150, t=150.0, p=76664, mu_n=16.2 mu_factor=0.48, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=151, t=151.0, p=76685, mu_n=2.1 mu_factor=0.06, dI=-2.932551319648094e-06, dg=0.0, K=10.0 -> Open long
# iter=152, t=152.0, p=76680, mu_n=-0.5 mu_factor=0.01, dI=2.932551319648094e-06, dg=-5.0, K=-10.0 -> Close long
# iter=153, t=153.0, p=76772, mu_n=9.2 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=154, t=154.0, p=76740, mu_n=-3.2 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=155, t=155.0, p=76707, mu_n=-3.3 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=156, t=156.0, p=76812, mu_n=10.5 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=157, t=157.0, p=76892, mu_n=8.0 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=158, t=158.0, p=76902, mu_n=1.0 mu_factor=0.03, dI=7.331378299120235e-07, dg=0.0, K=-10.0 -> Open short
# iter=159, t=159.0, p=76812, mu_n=-9.0 mu_factor=0.26, dI=-7.331378299120235e-07, dg=90.0, K=10.0 -> Close short
# iter=160, t=160.0, p=76722, mu_n=-9.0 mu_factor=0.26, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=161, t=161.0, p=76770, mu_n=4.8 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=162, t=162.0, p=76671, mu_n=-9.9 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=163, t=163.0, p=76694, mu_n=2.3 mu_factor=0.07, dI=0.0002375366568914956, dg=0.0, K=-10.0 -> Open short
# iter=164, t=164.0, p=76674, mu_n=-2.0 mu_factor=0.06, dI=-0.0002375366568914956, dg=20.0, K=10.0 -> Close short
# iter=165, t=165.0, p=76593, mu_n=-8.1 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=166, t=166.0, p=76519, mu_n=-7.4 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=167, t=167.0, p=76572, mu_n=5.3 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=168, t=168.0, p=76595, mu_n=2.3 mu_factor=0.07, dI=1.1730205278592376e-05, dg=0.0, K=-10.0 -> Open short
# iter=169, t=169.0, p=76622, mu_n=2.7 mu_factor=0.08, dI=-1.1730205278592376e-05, dg=-27.0, K=10.0 -> Close short
# iter=170, t=170.0, p=76623, mu_n=0.1 mu_factor=0.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=171, t=171.0, p=76623, mu_n=0.0 mu_factor=0.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=172, t=172.0, p=76589, mu_n=-3.4 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=173, t=173.0, p=76650, mu_n=6.1 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=174, t=174.0, p=76674, mu_n=2.4 mu_factor=0.07, dI=-2.1378299120234605e-05, dg=0.0, K=10.0 -> Open long
# iter=175, t=175.0, p=76744, mu_n=7.0 mu_factor=0.21, dI=2.1378299120234605e-05, dg=70.0, K=-10.0 -> Close long
# iter=176, t=176.0, p=76807, mu_n=6.3 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=177, t=177.0, p=76881, mu_n=7.4 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=178, t=178.0, p=76830, mu_n=-5.1 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=179, t=179.0, p=76936, mu_n=10.6 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=180, t=180.0, p=76946, mu_n=1.0 mu_factor=0.03, dI=-0.0001436950146627566, dg=0.0, K=10.0 -> Open long
# iter=181, t=181.0, p=76922, mu_n=-2.4 mu_factor=0.07, dI=0.0001436950146627566, dg=-24.0, K=-10.0 -> Close long
# iter=182, t=182.0, p=76881, mu_n=-4.1 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=183, t=183.0, p=76783, mu_n=-9.8 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=184, t=184.0, p=76773, mu_n=-1.0 mu_factor=0.03, dI=1.689149560117302e-05, dg=0.0, K=10.0 -> Open long
# iter=185, t=185.0, p=76755, mu_n=-1.8 mu_factor=0.05, dI=-1.689149560117302e-05, dg=-18.0, K=-10.0 -> Close long
# iter=186, t=186.0, p=76730, mu_n=-2.5 mu_factor=0.07, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=187, t=187.0, p=76748, mu_n=1.8 mu_factor=0.05, dI=9.501466275659823e-06, dg=0.0, K=-10.0 -> Open short
# iter=188, t=188.0, p=76781, mu_n=3.3 mu_factor=0.1, dI=-9.501466275659823e-06, dg=-33.0, K=10.0 -> Close short
# iter=189, t=189.0, p=76892, mu_n=11.1 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=190, t=190.0, p=76800, mu_n=-9.2 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=191, t=191.0, p=76838, mu_n=3.8 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=192, t=192.0, p=76836, mu_n=-0.2 mu_factor=0.01, dI=-3.1935483870967747e-05, dg=0.0, K=-10.0 -> Open short
# iter=193, t=193.0, p=76789, mu_n=-4.7 mu_factor=0.14, dI=3.1935483870967747e-05, dg=47.0, K=10.0 -> Close short
# iter=194, t=194.0, p=76857, mu_n=6.8 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=195, t=195.0, p=76835, mu_n=-2.2 mu_factor=0.06, dI=6.478005865102639e-05, dg=0.0, K=10.0 -> Open long
# iter=196, t=196.0, p=76765, mu_n=-7.0 mu_factor=0.21, dI=-6.478005865102639e-05, dg=-70.0, K=-10.0 -> Close long
# iter=197, t=197.0, p=76730, mu_n=-3.5 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=198, t=198.0, p=76739, mu_n=0.9 mu_factor=0.03, dI=0.0001436950146627566, dg=0.0, K=-10.0 -> Open short
# iter=199, t=199.0, p=76670, mu_n=-6.9 mu_factor=0.2, dI=-0.0001436950146627566, dg=69.0, K=10.0 -> Close short
# iter=200, t=200.0, p=76798, mu_n=12.8 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=201, t=201.0, p=76838, mu_n=4.0 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=202, t=202.0, p=76842, mu_n=0.4 mu_factor=0.01, dI=0.00013961876832844575, dg=0.0, K=-10.0 -> Open short
# iter=203, t=203.0, p=76837, mu_n=-0.5 mu_factor=0.01, dI=-0.00013961876832844575, dg=5.0, K=10.0 -> Close short
# iter=204, t=204.0, p=76912, mu_n=7.5 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=205, t=205.0, p=76945, mu_n=3.3 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# Итоговая прибыль: 0.0

# %% [markdown]
# ## 14.02.2022

# %%
alg.calc_alg0(p_arr_si_14, mu_arr_si_14, 1.)
# Out:
# iter=1, t=1.0, p=78210, mu_n=41.3 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=2, t=2.0, p=78181, mu_n=-2.9 mu_factor=0.07, dI=1e-06, dg=0.0, K=10.0 -> Open long
# iter=3, t=3.0, p=78377, mu_n=19.6 mu_factor=0.47, dI=-1e-06, dg=196.0, K=-10.0 -> Close long
# iter=4, t=4.0, p=78720, mu_n=34.3 mu_factor=0.83, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=5, t=5.0, p=78608, mu_n=-11.2 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=6, t=6.0, p=78510, mu_n=-9.8 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=7, t=7.0, p=78350, mu_n=-16.0 mu_factor=0.39, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=8, t=8.0, p=78440, mu_n=9.0 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=9, t=9.0, p=78408, mu_n=-3.2 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=10, t=10.0, p=78435, mu_n=2.7 mu_factor=0.07, dI=-0.00196, dg=0.0, K=10.0 -> Open long
# iter=11, t=11.0, p=78274, mu_n=-16.1 mu_factor=0.39, dI=0.00196, dg=-161.0, K=-10.0 -> Close long
# iter=12, t=12.0, p=78172, mu_n=-10.2 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=13, t=13.0, p=78200, mu_n=2.8 mu_factor=0.07, dI=0.00161, dg=0.0, K=-10.0 -> Open short
# iter=14, t=14.0, p=78209, mu_n=0.9 mu_factor=0.02, dI=-0.00161, dg=-9.0, K=10.0 -> Close short
# iter=15, t=15.0, p=78246, mu_n=3.7 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=16, t=16.0, p=78101, mu_n=-14.5 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=17, t=17.0, p=78146, mu_n=4.5 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=18, t=18.0, p=78005, mu_n=-14.1 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=19, t=19.0, p=77974, mu_n=-3.1 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=20, t=20.0, p=77860, mu_n=-11.4 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=21, t=21.0, p=77767, mu_n=-9.3 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=22, t=22.0, p=77715, mu_n=-5.2 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=23, t=23.0, p=77510, mu_n=-20.5 mu_factor=0.5, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=24, t=24.0, p=77731, mu_n=22.1 mu_factor=0.54, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=25, t=25.0, p=77866, mu_n=13.5 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=26, t=26.0, p=77883, mu_n=1.7 mu_factor=0.04, dI=-9e-05, dg=0.0, K=10.0 -> Open long
# iter=27, t=27.0, p=77891, mu_n=0.8 mu_factor=0.02, dI=9e-05, dg=8.0, K=-10.0 -> Close long
# iter=28, t=28.0, p=77729, mu_n=-16.2 mu_factor=0.39, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=29, t=29.0, p=77629, mu_n=-10.0 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=30, t=30.0, p=77583, mu_n=-4.6 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=31, t=31.0, p=77495, mu_n=-8.8 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=32, t=32.0, p=77394, mu_n=-10.1 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=33, t=33.0, p=77472, mu_n=7.8 mu_factor=0.19, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=34, t=34.0, p=77707, mu_n=23.5 mu_factor=0.57, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=35, t=35.0, p=77596, mu_n=-11.1 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=36, t=36.0, p=77488, mu_n=-10.8 mu_factor=0.26, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=37, t=37.0, p=77544, mu_n=5.6 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=38, t=38.0, p=77402, mu_n=-14.2 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=39, t=39.0, p=77479, mu_n=7.7 mu_factor=0.19, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=40, t=40.0, p=77376, mu_n=-10.3 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=41, t=41.0, p=77415, mu_n=3.9 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=42, t=42.0, p=77650, mu_n=23.5 mu_factor=0.57, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=43, t=43.0, p=77497, mu_n=-15.3 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=44, t=44.0, p=77405, mu_n=-9.2 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=45, t=45.0, p=77453, mu_n=4.8 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=46, t=46.0, p=77396, mu_n=-5.7 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=47, t=47.0, p=77299, mu_n=-9.7 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=48, t=48.0, p=77198, mu_n=-10.1 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=49, t=49.0, p=77213, mu_n=1.5 mu_factor=0.04, dI=-8e-05, dg=0.0, K=10.0 -> Open long
# iter=50, t=50.0, p=77276, mu_n=6.3 mu_factor=0.15, dI=8e-05, dg=63.0, K=-10.0 -> Close long
# iter=51, t=51.0, p=77212, mu_n=-6.4 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=52, t=52.0, p=77066, mu_n=-14.6 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=53, t=53.0, p=77157, mu_n=9.1 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=54, t=54.0, p=77160, mu_n=0.3 mu_factor=0.01, dI=-0.00063, dg=0.0, K=10.0 -> Open long
# iter=55, t=55.0, p=77121, mu_n=-3.9 mu_factor=0.09, dI=0.00063, dg=-39.0, K=-10.0 -> Close long
# iter=56, t=56.0, p=77198, mu_n=7.7 mu_factor=0.19, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=57, t=57.0, p=77081, mu_n=-11.7 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=58, t=58.0, p=77019, mu_n=-6.2 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=59, t=59.0, p=77000, mu_n=-1.9 mu_factor=0.05, dI=0.00039, dg=0.0, K=10.0 -> Open long
# iter=60, t=60.0, p=77075, mu_n=7.5 mu_factor=0.18, dI=-0.00039, dg=75.0, K=-10.0 -> Close long
# iter=61, t=61.0, p=77099, mu_n=2.4 mu_factor=0.06, dI=-0.00075, dg=0.0, K=10.0 -> Open long
# iter=62, t=62.0, p=77238, mu_n=13.9 mu_factor=0.34, dI=0.00075, dg=139.0, K=-10.0 -> Close long
# iter=63, t=63.0, p=77185, mu_n=-5.3 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=64, t=64.0, p=77079, mu_n=-10.6 mu_factor=0.26, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=65, t=65.0, p=77142, mu_n=6.3 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=66, t=66.0, p=77088, mu_n=-5.4 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=67, t=67.0, p=77180, mu_n=9.2 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=68, t=68.0, p=77263, mu_n=8.3 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=69, t=69.0, p=77339, mu_n=7.6 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=70, t=70.0, p=77394, mu_n=5.5 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=71, t=71.0, p=77413, mu_n=1.9 mu_factor=0.05, dI=-0.00139, dg=0.0, K=10.0 -> Open long
# iter=72, t=72.0, p=77477, mu_n=6.4 mu_factor=0.15, dI=0.00139, dg=64.0, K=-10.0 -> Close long
# iter=73, t=73.0, p=77475, mu_n=-0.2 mu_factor=0.0, dI=-0.00064, dg=0.0, K=-10.0 -> Open short
# iter=74, t=74.0, p=77551, mu_n=7.6 mu_factor=0.18, dI=0.00064, dg=-76.0, K=10.0 -> Close short
# iter=75, t=75.0, p=77532, mu_n=-1.9 mu_factor=0.05, dI=-0.00076, dg=0.0, K=-10.0 -> Open short
# iter=76, t=76.0, p=77494, mu_n=-3.8 mu_factor=0.09, dI=0.00076, dg=38.0, K=10.0 -> Close short
# iter=77, t=77.0, p=77604, mu_n=11.0 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=78, t=78.0, p=77589, mu_n=-1.5 mu_factor=0.04, dI=0.00038, dg=0.0, K=10.0 -> Open long
# iter=79, t=79.0, p=77645, mu_n=5.6 mu_factor=0.14, dI=-0.00038, dg=56.0, K=-10.0 -> Close long
# iter=80, t=80.0, p=77690, mu_n=4.5 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=81, t=81.0, p=77697, mu_n=0.7 mu_factor=0.02, dI=-0.00056, dg=0.0, K=10.0 -> Open long
# iter=82, t=82.0, p=77741, mu_n=4.4 mu_factor=0.11, dI=0.00056, dg=44.0, K=-10.0 -> Close long
# iter=83, t=83.0, p=77701, mu_n=-4.0 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=84, t=84.0, p=77838, mu_n=13.7 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=85, t=85.0, p=77795, mu_n=-4.3 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=86, t=86.0, p=77748, mu_n=-4.7 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=87, t=87.0, p=77674, mu_n=-7.4 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=88, t=88.0, p=77701, mu_n=2.7 mu_factor=0.07, dI=-0.00044, dg=0.0, K=10.0 -> Open long
# iter=89, t=89.0, p=77650, mu_n=-5.1 mu_factor=0.12, dI=0.00044, dg=-51.0, K=-10.0 -> Close long
# iter=90, t=90.0, p=77677, mu_n=2.7 mu_factor=0.07, dI=0.00051, dg=0.0, K=-10.0 -> Open short
# iter=91, t=91.0, p=77787, mu_n=11.0 mu_factor=0.27, dI=-0.00051, dg=-110.0, K=10.0 -> Close short
# iter=92, t=92.0, p=77810, mu_n=2.3 mu_factor=0.06, dI=-0.0011, dg=0.0, K=10.0 -> Open long
# iter=93, t=93.0, p=77800, mu_n=-1.0 mu_factor=0.02, dI=0.0011, dg=-10.0, K=-10.0 -> Close long
# iter=94, t=94.0, p=77687, mu_n=-11.3 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=95, t=95.0, p=77750, mu_n=6.3 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=96, t=96.0, p=77879, mu_n=12.9 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=97, t=97.0, p=77946, mu_n=6.7 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=98, t=98.0, p=77874, mu_n=-7.2 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=99, t=99.0, p=77847, mu_n=-2.7 mu_factor=0.07, dI=0.0001, dg=0.0, K=10.0 -> Open long
# iter=100, t=100.0, p=77821, mu_n=-2.6 mu_factor=0.06, dI=-0.0001, dg=-26.0, K=-10.0 -> Close long
# iter=101, t=101.0, p=77874, mu_n=5.3 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=102, t=102.0, p=77840, mu_n=-3.4 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=103, t=103.0, p=77740, mu_n=-10.0 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=104, t=104.0, p=77572, mu_n=-16.8 mu_factor=0.41, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=105, t=105.0, p=77380, mu_n=-19.2 mu_factor=0.46, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=106, t=106.0, p=77390, mu_n=1.0 mu_factor=0.02, dI=0.00026, dg=0.0, K=-10.0 -> Open short
# iter=107, t=107.0, p=77215, mu_n=-17.5 mu_factor=0.42, dI=-0.00026, dg=175.0, K=10.0 -> Close short
# iter=108, t=108.0, p=77140, mu_n=-7.5 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=109, t=109.0, p=77200, mu_n=6.0 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=110, t=110.0, p=77226, mu_n=2.6 mu_factor=0.06, dI=0.00175, dg=0.0, K=-10.0 -> Open short
# iter=111, t=111.0, p=77261, mu_n=3.5 mu_factor=0.08, dI=-0.00175, dg=-35.0, K=10.0 -> Close short
# iter=112, t=112.0, p=77308, mu_n=4.7 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=113, t=113.0, p=77331, mu_n=2.3 mu_factor=0.06, dI=-0.00035, dg=0.0, K=10.0 -> Open long
# iter=114, t=114.0, p=77436, mu_n=10.5 mu_factor=0.25, dI=0.00035, dg=105.0, K=-10.0 -> Close long
# iter=115, t=115.0, p=77520, mu_n=8.4 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=116, t=116.0, p=77609, mu_n=8.9 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=117, t=117.0, p=77650, mu_n=4.1 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=118, t=118.0, p=77536, mu_n=-11.4 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=119, t=119.0, p=77624, mu_n=8.8 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=120, t=120.0, p=77760, mu_n=13.6 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=121, t=121.0, p=77775, mu_n=1.5 mu_factor=0.04, dI=-0.00105, dg=0.0, K=10.0 -> Open long
# iter=122, t=122.0, p=77690, mu_n=-8.5 mu_factor=0.21, dI=0.00105, dg=-85.0, K=-10.0 -> Close long
# iter=123, t=123.0, p=77711, mu_n=2.1 mu_factor=0.05, dI=0.00085, dg=0.0, K=-10.0 -> Open short
# iter=124, t=124.0, p=77585, mu_n=-12.6 mu_factor=0.31, dI=-0.00085, dg=126.0, K=10.0 -> Close short
# iter=125, t=125.0, p=77588, mu_n=0.3 mu_factor=0.01, dI=0.00126, dg=0.0, K=-10.0 -> Open short
# iter=126, t=126.0, p=77544, mu_n=-4.4 mu_factor=0.11, dI=-0.00126, dg=44.0, K=10.0 -> Close short
# iter=127, t=127.0, p=77751, mu_n=20.7 mu_factor=0.5, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=128, t=128.0, p=77791, mu_n=4.0 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=129, t=129.0, p=77775, mu_n=-1.6 mu_factor=0.04, dI=0.00044, dg=0.0, K=10.0 -> Open long
# iter=130, t=130.0, p=77826, mu_n=5.1 mu_factor=0.12, dI=-0.00044, dg=51.0, K=-10.0 -> Close long
# iter=131, t=131.0, p=77726, mu_n=-10.0 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=132, t=132.0, p=77623, mu_n=-10.3 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=133, t=133.0, p=77548, mu_n=-7.5 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=134, t=134.0, p=77332, mu_n=-21.6 mu_factor=0.52, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=135, t=135.0, p=77068, mu_n=-26.4 mu_factor=0.64, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=136, t=136.0, p=76815, mu_n=-25.3 mu_factor=0.61, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=137, t=137.0, p=76971, mu_n=15.6 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=138, t=138.0, p=76896, mu_n=-7.5 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=139, t=139.0, p=76867, mu_n=-2.9 mu_factor=0.07, dI=-0.00051, dg=0.0, K=-10.0 -> Open short
# iter=140, t=140.0, p=76878, mu_n=1.1 mu_factor=0.03, dI=0.00051, dg=-11.0, K=10.0 -> Close short
# iter=141, t=141.0, p=76726, mu_n=-15.2 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=142, t=142.0, p=76711, mu_n=-1.5 mu_factor=0.04, dI=-0.00011, dg=0.0, K=-10.0 -> Open short
# iter=143, t=143.0, p=76628, mu_n=-8.3 mu_factor=0.2, dI=0.00011, dg=83.0, K=10.0 -> Close short
# iter=144, t=144.0, p=76675, mu_n=4.7 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=145, t=145.0, p=76741, mu_n=6.6 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=146, t=146.0, p=76841, mu_n=10.0 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=147, t=147.0, p=76728, mu_n=-11.3 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=148, t=148.0, p=76830, mu_n=10.2 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=149, t=149.0, p=76874, mu_n=4.4 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=150, t=150.0, p=77017, mu_n=14.3 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=151, t=151.0, p=76987, mu_n=-3.0 mu_factor=0.07, dI=0.00083, dg=0.0, K=10.0 -> Open long
# iter=152, t=152.0, p=76900, mu_n=-8.7 mu_factor=0.21, dI=-0.00083, dg=-87.0, K=-10.0 -> Close long
# iter=153, t=153.0, p=76970, mu_n=7.0 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=154, t=154.0, p=76989, mu_n=1.9 mu_factor=0.05, dI=0.00087, dg=0.0, K=-10.0 -> Open short
# iter=155, t=155.0, p=76927, mu_n=-6.2 mu_factor=0.15, dI=-0.00087, dg=62.0, K=10.0 -> Close short
# iter=156, t=156.0, p=76755, mu_n=-17.2 mu_factor=0.42, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=157, t=157.0, p=76823, mu_n=6.8 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=158, t=158.0, p=76960, mu_n=13.7 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=159, t=159.0, p=76902, mu_n=-5.8 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=160, t=160.0, p=76899, mu_n=-0.3 mu_factor=0.01, dI=0.00062, dg=0.0, K=10.0 -> Open long
# iter=161, t=161.0, p=76882, mu_n=-1.7 mu_factor=0.04, dI=-0.00062, dg=-17.0, K=-10.0 -> Close long
# iter=162, t=162.0, p=76797, mu_n=-8.5 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=163, t=163.0, p=76854, mu_n=5.7 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=164, t=164.0, p=76924, mu_n=7.0 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=165, t=165.0, p=76990, mu_n=6.6 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=166, t=166.0, p=77049, mu_n=5.9 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=167, t=167.0, p=77003, mu_n=-4.6 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=168, t=168.0, p=77123, mu_n=12.0 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=169, t=169.0, p=77172, mu_n=4.9 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=170, t=170.0, p=77071, mu_n=-10.1 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=171, t=171.0, p=77134, mu_n=6.3 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=172, t=172.0, p=77256, mu_n=12.2 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=173, t=173.0, p=77125, mu_n=-13.1 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=174, t=174.0, p=77079, mu_n=-4.6 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=175, t=175.0, p=77091, mu_n=1.2 mu_factor=0.03, dI=0.00017, dg=0.0, K=-10.0 -> Open short
# iter=176, t=176.0, p=76969, mu_n=-12.2 mu_factor=0.3, dI=-0.00017, dg=122.0, K=10.0 -> Close short
# iter=177, t=177.0, p=77044, mu_n=7.5 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=178, t=178.0, p=77154, mu_n=11.0 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=179, t=179.0, p=77210, mu_n=5.6 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=180, t=180.0, p=77243, mu_n=3.3 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=181, t=181.0, p=77217, mu_n=-2.6 mu_factor=0.06, dI=0.00122, dg=0.0, K=10.0 -> Open long
# iter=182, t=182.0, p=77302, mu_n=8.5 mu_factor=0.21, dI=-0.00122, dg=85.0, K=-10.0 -> Close long
# iter=183, t=183.0, p=77141, mu_n=-16.1 mu_factor=0.39, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=184, t=184.0, p=77344, mu_n=20.3 mu_factor=0.49, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=185, t=185.0, p=77260, mu_n=-8.4 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=186, t=186.0, p=77320, mu_n=6.0 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=187, t=187.0, p=77444, mu_n=12.4 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=188, t=188.0, p=77382, mu_n=-6.2 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=189, t=189.0, p=77490, mu_n=10.8 mu_factor=0.26, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=190, t=190.0, p=77536, mu_n=4.6 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=191, t=191.0, p=77517, mu_n=-1.9 mu_factor=0.05, dI=-0.00085, dg=0.0, K=-10.0 -> Open short
# iter=192, t=192.0, p=77510, mu_n=-0.7 mu_factor=0.02, dI=0.00085, dg=7.0, K=10.0 -> Close short
# iter=193, t=193.0, p=77494, mu_n=-1.6 mu_factor=0.04, dI=7e-05, dg=0.0, K=10.0 -> Open long
# iter=194, t=194.0, p=77569, mu_n=7.5 mu_factor=0.18, dI=-7e-05, dg=75.0, K=-10.0 -> Close long
# iter=195, t=195.0, p=77482, mu_n=-8.7 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=196, t=196.0, p=77544, mu_n=6.2 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=197, t=197.0, p=77372, mu_n=-17.2 mu_factor=0.42, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=198, t=198.0, p=77455, mu_n=8.3 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=199, t=199.0, p=77187, mu_n=-26.8 mu_factor=0.65, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=200, t=200.0, p=77362, mu_n=17.5 mu_factor=0.42, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=201, t=201.0, p=77412, mu_n=5.0 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=202, t=202.0, p=77268, mu_n=-14.4 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=203, t=203.0, p=77199, mu_n=-6.9 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=204, t=204.0, p=77131, mu_n=-6.8 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=205, t=205.0, p=77210, mu_n=7.9 mu_factor=0.19, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=206, t=206.0, p=77385, mu_n=17.5 mu_factor=0.42, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=207, t=207.0, p=77183, mu_n=-20.2 mu_factor=0.49, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=208, t=208.0, p=77179, mu_n=-0.4 mu_factor=0.01, dI=-0.00075, dg=0.0, K=-10.0 -> Open short
# iter=209, t=209.0, p=77251, mu_n=7.2 mu_factor=0.17, dI=0.00075, dg=-72.0, K=10.0 -> Close short
# iter=210, t=210.0, p=77226, mu_n=-2.5 mu_factor=0.06, dI=-0.00072, dg=0.0, K=-10.0 -> Open short
# iter=211, t=211.0, p=77308, mu_n=8.2 mu_factor=0.2, dI=0.00072, dg=-82.0, K=10.0 -> Close short
# iter=212, t=212.0, p=77437, mu_n=12.9 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=213, t=213.0, p=77437, mu_n=0.0 mu_factor=0.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=214, t=214.0, p=77506, mu_n=6.9 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=215, t=215.0, p=77750, mu_n=24.4 mu_factor=0.59, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=216, t=216.0, p=77750, mu_n=0.0 mu_factor=0.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=217, t=217.0, p=77840, mu_n=9.0 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=218, t=218.0, p=77984, mu_n=14.4 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=219, t=219.0, p=77885, mu_n=-9.9 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=220, t=220.0, p=77983, mu_n=9.8 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=221, t=221.0, p=77866, mu_n=-11.7 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=222, t=222.0, p=77930, mu_n=6.4 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=223, t=223.0, p=77997, mu_n=6.7 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=224, t=224.0, p=77845, mu_n=-15.2 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=225, t=225.0, p=77740, mu_n=-10.5 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=226, t=226.0, p=77754, mu_n=1.4 mu_factor=0.03, dI=-0.00082, dg=0.0, K=10.0 -> Open long
# iter=227, t=227.0, p=77757, mu_n=0.3 mu_factor=0.01, dI=0.00082, dg=3.0, K=-10.0 -> Close long
# iter=228, t=228.0, p=77689, mu_n=-6.8 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=229, t=229.0, p=77556, mu_n=-13.3 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=230, t=230.0, p=77498, mu_n=-5.8 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=231, t=231.0, p=77454, mu_n=-4.4 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=232, t=232.0, p=77410, mu_n=-4.4 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=233, t=233.0, p=77521, mu_n=11.1 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=234, t=234.0, p=77503, mu_n=-1.8 mu_factor=0.04, dI=-3e-05, dg=0.0, K=-10.0 -> Open short
# iter=235, t=235.0, p=77498, mu_n=-0.5 mu_factor=0.01, dI=3e-05, dg=5.0, K=10.0 -> Close short
# Итоговая прибыль: 5.0

# %% [markdown]
# ## 21.02.2022
# "Дикий день"

# %%
alg.calc_alg0(p_arr_si_21, mu_arr_si_21, 1.)
# Out:
# iter=1, t=1.0, p=77608, mu_n=23.7 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=2, t=2.0, p=77622, mu_n=1.4 mu_factor=0.06, dI=1e-06, dg=0.0, K=-10.0 -> Open short
# iter=3, t=3.0, p=77493, mu_n=-12.9 mu_factor=0.54, dI=-1e-06, dg=129.0, K=10.0 -> Close short
# iter=4, t=4.0, p=77461, mu_n=-3.2 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=5, t=5.0, p=77543, mu_n=8.2 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=6, t=6.0, p=77610, mu_n=6.7 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=7, t=7.0, p=77618, mu_n=0.8 mu_factor=0.03, dI=0.00129, dg=0.0, K=-10.0 -> Open short
# iter=8, t=8.0, p=77560, mu_n=-5.8 mu_factor=0.24, dI=-0.00129, dg=58.0, K=10.0 -> Close short
# iter=9, t=9.0, p=77470, mu_n=-9.0 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=10, t=10.0, p=77326, mu_n=-14.4 mu_factor=0.61, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=11, t=11.0, p=77350, mu_n=2.4 mu_factor=0.1, dI=0.00058, dg=0.0, K=-10.0 -> Open short
# iter=12, t=12.0, p=77327, mu_n=-2.3 mu_factor=0.1, dI=-0.00058, dg=23.0, K=10.0 -> Close short
# iter=13, t=13.0, p=77400, mu_n=7.3 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=14, t=14.0, p=77395, mu_n=-0.5 mu_factor=0.02, dI=0.00023, dg=0.0, K=10.0 -> Open long
# iter=15, t=15.0, p=77323, mu_n=-7.2 mu_factor=0.3, dI=-0.00023, dg=-72.0, K=-10.0 -> Close long
# iter=16, t=16.0, p=77332, mu_n=0.9 mu_factor=0.04, dI=0.00072, dg=0.0, K=-10.0 -> Open short
# iter=17, t=17.0, p=77425, mu_n=9.3 mu_factor=0.39, dI=-0.00072, dg=-93.0, K=10.0 -> Close short
# iter=18, t=18.0, p=77359, mu_n=-6.6 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=19, t=19.0, p=77398, mu_n=3.9 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=20, t=20.0, p=77332, mu_n=-6.6 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=21, t=21.0, p=77397, mu_n=6.5 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=22, t=22.0, p=77449, mu_n=5.2 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=23, t=23.0, p=77420, mu_n=-2.9 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=24, t=24.0, p=77457, mu_n=3.7 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=25, t=25.0, p=77478, mu_n=2.1 mu_factor=0.09, dI=-0.00093, dg=0.0, K=10.0 -> Open long
# iter=26, t=26.0, p=77536, mu_n=5.8 mu_factor=0.24, dI=0.00093, dg=58.0, K=-10.0 -> Close long
# iter=27, t=27.0, p=77531, mu_n=-0.5 mu_factor=0.02, dI=-0.00058, dg=0.0, K=-10.0 -> Open short
# iter=28, t=28.0, p=77632, mu_n=10.1 mu_factor=0.43, dI=0.00058, dg=-101.0, K=10.0 -> Close short
# iter=29, t=29.0, p=77689, mu_n=5.7 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=30, t=30.0, p=77773, mu_n=8.4 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=31, t=31.0, p=77803, mu_n=3.0 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=32, t=32.0, p=77786, mu_n=-1.7 mu_factor=0.07, dI=-0.00101, dg=0.0, K=-10.0 -> Open short
# iter=33, t=33.0, p=77797, mu_n=1.1 mu_factor=0.05, dI=0.00101, dg=-11.0, K=10.0 -> Close short
# iter=34, t=34.0, p=77872, mu_n=7.5 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=35, t=35.0, p=77950, mu_n=7.8 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=36, t=36.0, p=77970, mu_n=2.0 mu_factor=0.08, dI=-0.00011, dg=0.0, K=10.0 -> Open long
# iter=37, t=37.0, p=78024, mu_n=5.4 mu_factor=0.23, dI=0.00011, dg=54.0, K=-10.0 -> Close long
# iter=38, t=38.0, p=78166, mu_n=14.2 mu_factor=0.6, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=39, t=39.0, p=78289, mu_n=12.3 mu_factor=0.52, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=40, t=40.0, p=78228, mu_n=-6.1 mu_factor=0.26, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=41, t=41.0, p=78275, mu_n=4.7 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=42, t=42.0, p=78303, mu_n=2.8 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=43, t=43.0, p=78302, mu_n=-0.1 mu_factor=0.0, dI=-0.00054, dg=0.0, K=-10.0 -> Open short
# iter=44, t=44.0, p=78266, mu_n=-3.6 mu_factor=0.15, dI=0.00054, dg=36.0, K=10.0 -> Close short
# iter=45, t=45.0, p=78234, mu_n=-3.2 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=46, t=46.0, p=78183, mu_n=-5.1 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=47, t=47.0, p=78273, mu_n=9.0 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=48, t=48.0, p=78413, mu_n=14.0 mu_factor=0.59, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=49, t=49.0, p=78470, mu_n=5.7 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=50, t=50.0, p=78528, mu_n=5.8 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=51, t=51.0, p=78595, mu_n=6.7 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=52, t=52.0, p=78676, mu_n=8.1 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=53, t=53.0, p=78595, mu_n=-8.1 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=54, t=54.0, p=78627, mu_n=3.2 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=55, t=55.0, p=78602, mu_n=-2.5 mu_factor=0.11, dI=0.00036, dg=0.0, K=10.0 -> Open long
# iter=56, t=56.0, p=78629, mu_n=2.7 mu_factor=0.11, dI=-0.00036, dg=27.0, K=-10.0 -> Close long
# iter=57, t=57.0, p=78588, mu_n=-4.1 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=58, t=58.0, p=78573, mu_n=-1.5 mu_factor=0.06, dI=-0.00027, dg=0.0, K=-10.0 -> Open short
# iter=59, t=59.0, p=78622, mu_n=4.9 mu_factor=0.21, dI=0.00027, dg=-49.0, K=10.0 -> Close short
# iter=60, t=60.0, p=78559, mu_n=-6.3 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=61, t=61.0, p=78476, mu_n=-8.3 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=62, t=62.0, p=78489, mu_n=1.3 mu_factor=0.05, dI=-0.00049, dg=0.0, K=10.0 -> Open long
# iter=63, t=63.0, p=78517, mu_n=2.8 mu_factor=0.12, dI=0.00049, dg=28.0, K=-10.0 -> Close long
# iter=64, t=64.0, p=78509, mu_n=-0.8 mu_factor=0.03, dI=-0.00028, dg=0.0, K=-10.0 -> Open short
# iter=65, t=65.0, p=78514, mu_n=0.5 mu_factor=0.02, dI=0.00028, dg=-5.0, K=10.0 -> Close short
# iter=66, t=66.0, p=78509, mu_n=-0.5 mu_factor=0.02, dI=-5e-05, dg=0.0, K=-10.0 -> Open short
# iter=67, t=67.0, p=78688, mu_n=17.9 mu_factor=0.76, dI=5e-05, dg=-179.0, K=10.0 -> Close short
# iter=68, t=68.0, p=78864, mu_n=17.6 mu_factor=0.74, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=69, t=69.0, p=78928, mu_n=6.4 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=70, t=70.0, p=78866, mu_n=-6.2 mu_factor=0.26, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=71, t=71.0, p=78791, mu_n=-7.5 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=72, t=72.0, p=78932, mu_n=14.1 mu_factor=0.59, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=73, t=73.0, p=78840, mu_n=-9.2 mu_factor=0.39, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=74, t=74.0, p=78934, mu_n=9.4 mu_factor=0.4, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=75, t=75.0, p=79019, mu_n=8.5 mu_factor=0.36, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=76, t=76.0, p=79006, mu_n=-1.3 mu_factor=0.05, dI=-0.00179, dg=0.0, K=-10.0 -> Open short
# iter=77, t=77.0, p=78993, mu_n=-1.3 mu_factor=0.05, dI=0.00179, dg=13.0, K=10.0 -> Close short
# iter=78, t=78.0, p=78883, mu_n=-11.0 mu_factor=0.46, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=79, t=79.0, p=78628, mu_n=-25.5 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=80, t=80.0, p=78654, mu_n=2.6 mu_factor=0.1, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=81, t=81.0, p=78633, mu_n=-2.1 mu_factor=0.08, dI=0.00013, dg=0.0, K=10.0 -> Open long
# iter=82, t=82.0, p=78639, mu_n=0.6 mu_factor=0.02, dI=-0.00013, dg=6.0, K=-10.0 -> Close long
# iter=83, t=83.0, p=78861, mu_n=22.2 mu_factor=0.87, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=84, t=84.0, p=78734, mu_n=-12.7 mu_factor=0.5, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=85, t=85.0, p=78653, mu_n=-8.1 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=86, t=86.0, p=78649, mu_n=-0.4 mu_factor=0.02, dI=-6e-05, dg=0.0, K=-10.0 -> Open short
# iter=87, t=87.0, p=78644, mu_n=-0.5 mu_factor=0.02, dI=6e-05, dg=5.0, K=10.0 -> Close short
# iter=88, t=88.0, p=78725, mu_n=8.1 mu_factor=0.32, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=89, t=89.0, p=78951, mu_n=22.6 mu_factor=0.89, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=90, t=90.0, p=78917, mu_n=-3.4 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=91, t=91.0, p=79020, mu_n=10.3 mu_factor=0.4, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=92, t=92.0, p=79153, mu_n=13.3 mu_factor=0.52, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=93, t=93.0, p=79172, mu_n=1.9 mu_factor=0.07, dI=5e-05, dg=0.0, K=-10.0 -> Open short
# iter=94, t=94.0, p=79124, mu_n=-4.8 mu_factor=0.19, dI=-5e-05, dg=48.0, K=10.0 -> Close short
# iter=95, t=95.0, p=79184, mu_n=6.0 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=96, t=96.0, p=79062, mu_n=-12.2 mu_factor=0.48, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=97, t=97.0, p=79005, mu_n=-5.7 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=98, t=98.0, p=78973, mu_n=-3.2 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=99, t=99.0, p=79032, mu_n=5.9 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=100, t=100.0, p=79042, mu_n=1.0 mu_factor=0.04, dI=0.00048, dg=0.0, K=-10.0 -> Open short
# iter=101, t=101.0, p=79139, mu_n=9.7 mu_factor=0.38, dI=-0.00048, dg=-97.0, K=10.0 -> Close short
# iter=102, t=102.0, p=79019, mu_n=-12.0 mu_factor=0.47, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=103, t=103.0, p=79077, mu_n=5.8 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=104, t=104.0, p=78966, mu_n=-11.1 mu_factor=0.44, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=105, t=105.0, p=79063, mu_n=9.7 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=106, t=106.0, p=79086, mu_n=2.3 mu_factor=0.09, dI=-0.00097, dg=0.0, K=10.0 -> Open long
# iter=107, t=107.0, p=79185, mu_n=9.9 mu_factor=0.39, dI=0.00097, dg=99.0, K=-10.0 -> Close long
# iter=108, t=108.0, p=79232, mu_n=4.7 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=109, t=109.0, p=79260, mu_n=2.8 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=110, t=110.0, p=79204, mu_n=-5.6 mu_factor=0.22, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=111, t=111.0, p=79231, mu_n=2.7 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=112, t=112.0, p=79227, mu_n=-0.4 mu_factor=0.02, dI=-0.00099, dg=0.0, K=-10.0 -> Open short
# iter=113, t=113.0, p=79177, mu_n=-5.0 mu_factor=0.2, dI=0.00099, dg=50.0, K=10.0 -> Close short
# iter=114, t=114.0, p=79330, mu_n=15.3 mu_factor=0.6, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=115, t=115.0, p=79277, mu_n=-5.3 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=116, t=116.0, p=79304, mu_n=2.7 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=117, t=117.0, p=79293, mu_n=-1.1 mu_factor=0.04, dI=0.0005, dg=0.0, K=10.0 -> Open long
# iter=118, t=118.0, p=79349, mu_n=5.6 mu_factor=0.22, dI=-0.0005, dg=56.0, K=-10.0 -> Close long
# iter=119, t=119.0, p=79394, mu_n=4.5 mu_factor=0.18, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=120, t=120.0, p=79490, mu_n=9.6 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=121, t=121.0, p=79458, mu_n=-3.2 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=122, t=122.0, p=79571, mu_n=11.3 mu_factor=0.44, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=123, t=123.0, p=79641, mu_n=7.0 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=124, t=124.0, p=79657, mu_n=1.6 mu_factor=0.06, dI=-0.00056, dg=0.0, K=10.0 -> Open long
# iter=125, t=125.0, p=79845, mu_n=18.8 mu_factor=0.74, dI=0.00056, dg=188.0, K=-10.0 -> Close long
# iter=126, t=126.0, p=79718, mu_n=-12.7 mu_factor=0.5, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=127, t=127.0, p=79850, mu_n=13.2 mu_factor=0.52, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=128, t=128.0, p=79703, mu_n=-14.7 mu_factor=0.58, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=129, t=129.0, p=79612, mu_n=-9.1 mu_factor=0.36, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=130, t=130.0, p=79412, mu_n=-20.0 mu_factor=0.78, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=131, t=131.0, p=79524, mu_n=11.2 mu_factor=0.44, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=132, t=132.0, p=79400, mu_n=-12.4 mu_factor=0.49, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=133, t=133.0, p=79336, mu_n=-6.4 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=134, t=134.0, p=79409, mu_n=7.3 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=135, t=135.0, p=79389, mu_n=-2.0 mu_factor=0.08, dI=-0.00188, dg=0.0, K=-10.0 -> Open short
# iter=136, t=136.0, p=79366, mu_n=-2.3 mu_factor=0.09, dI=0.00188, dg=23.0, K=10.0 -> Close short
# iter=137, t=137.0, p=79481, mu_n=11.5 mu_factor=0.45, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=138, t=138.0, p=79313, mu_n=-16.8 mu_factor=0.66, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=139, t=139.0, p=79141, mu_n=-17.2 mu_factor=0.67, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=140, t=140.0, p=79051, mu_n=-9.0 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=141, t=141.0, p=78974, mu_n=-7.7 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=142, t=142.0, p=79032, mu_n=5.8 mu_factor=0.23, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=143, t=143.0, p=79257, mu_n=22.5 mu_factor=0.88, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=144, t=144.0, p=79142, mu_n=-11.5 mu_factor=0.45, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=145, t=145.0, p=79445, mu_n=30.3 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=146, t=146.0, p=79181, mu_n=-26.4 mu_factor=0.87, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=147, t=147.0, p=79119, mu_n=-6.2 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=148, t=148.0, p=79137, mu_n=1.8 mu_factor=0.06, dI=0.00023, dg=0.0, K=-10.0 -> Open short
# iter=149, t=149.0, p=79308, mu_n=17.1 mu_factor=0.56, dI=-0.00023, dg=-171.0, K=10.0 -> Close short
# iter=150, t=150.0, p=79203, mu_n=-10.5 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=151, t=151.0, p=79221, mu_n=1.8 mu_factor=0.06, dI=-0.00171, dg=0.0, K=10.0 -> Open long
# iter=152, t=152.0, p=79340, mu_n=11.9 mu_factor=0.39, dI=0.00171, dg=119.0, K=-10.0 -> Close long
# iter=153, t=153.0, p=79294, mu_n=-4.6 mu_factor=0.15, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=154, t=154.0, p=79317, mu_n=2.3 mu_factor=0.08, dI=-0.00119, dg=0.0, K=10.0 -> Open long
# iter=155, t=155.0, p=79553, mu_n=23.6 mu_factor=0.78, dI=0.00119, dg=236.0, K=-10.0 -> Close long
# iter=156, t=156.0, p=79763, mu_n=21.0 mu_factor=0.69, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=157, t=157.0, p=79690, mu_n=-7.3 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=158, t=158.0, p=79762, mu_n=7.2 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=159, t=159.0, p=79753, mu_n=-0.9 mu_factor=0.03, dI=-0.00236, dg=0.0, K=-10.0 -> Open short
# iter=160, t=160.0, p=79773, mu_n=2.0 mu_factor=0.07, dI=0.00236, dg=-20.0, K=10.0 -> Close short
# iter=161, t=161.0, p=79909, mu_n=13.6 mu_factor=0.45, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=162, t=162.0, p=80069, mu_n=16.0 mu_factor=0.53, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=163, t=163.0, p=79969, mu_n=-10.0 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=164, t=164.0, p=80138, mu_n=16.9 mu_factor=0.56, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=165, t=165.0, p=80043, mu_n=-9.5 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=166, t=166.0, p=79697, mu_n=-34.6 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=167, t=167.0, p=79784, mu_n=8.7 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=168, t=168.0, p=79729, mu_n=-5.5 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=169, t=169.0, p=79704, mu_n=-2.5 mu_factor=0.07, dI=-0.0002, dg=0.0, K=-10.0 -> Open short
# iter=170, t=170.0, p=79960, mu_n=25.6 mu_factor=0.74, dI=0.0002, dg=-256.0, K=10.0 -> Close short
# iter=171, t=171.0, p=79944, mu_n=-1.6 mu_factor=0.05, dI=-0.00256, dg=0.0, K=-10.0 -> Open short
# iter=172, t=172.0, p=79884, mu_n=-6.0 mu_factor=0.17, dI=0.00256, dg=60.0, K=10.0 -> Close short
# iter=173, t=173.0, p=79860, mu_n=-2.4 mu_factor=0.07, dI=0.0006, dg=0.0, K=10.0 -> Open long
# iter=174, t=174.0, p=79679, mu_n=-18.1 mu_factor=0.52, dI=-0.0006, dg=-181.0, K=-10.0 -> Close long
# iter=175, t=175.0, p=79843, mu_n=16.4 mu_factor=0.47, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=176, t=176.0, p=79590, mu_n=-25.3 mu_factor=0.73, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=177, t=177.0, p=79394, mu_n=-19.6 mu_factor=0.57, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=178, t=178.0, p=79166, mu_n=-22.8 mu_factor=0.66, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=179, t=179.0, p=79345, mu_n=17.9 mu_factor=0.52, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=180, t=180.0, p=79198, mu_n=-14.7 mu_factor=0.42, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=181, t=181.0, p=79270, mu_n=7.2 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=182, t=182.0, p=79273, mu_n=0.3 mu_factor=0.01, dI=0.00181, dg=0.0, K=-10.0 -> Open short
# iter=183, t=183.0, p=79372, mu_n=9.9 mu_factor=0.29, dI=-0.00181, dg=-99.0, K=10.0 -> Close short
# iter=184, t=184.0, p=79486, mu_n=11.4 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=185, t=185.0, p=79273, mu_n=-21.3 mu_factor=0.62, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=186, t=186.0, p=79322, mu_n=4.9 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=187, t=187.0, p=79601, mu_n=27.9 mu_factor=0.81, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=188, t=188.0, p=79495, mu_n=-10.6 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=189, t=189.0, p=79501, mu_n=0.6 mu_factor=0.02, dI=-0.00099, dg=0.0, K=10.0 -> Open long
# iter=190, t=190.0, p=79328, mu_n=-17.3 mu_factor=0.5, dI=0.00099, dg=-173.0, K=-10.0 -> Close long
# iter=191, t=191.0, p=79125, mu_n=-20.3 mu_factor=0.59, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=192, t=192.0, p=79369, mu_n=24.4 mu_factor=0.71, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=193, t=193.0, p=79500, mu_n=13.1 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=194, t=194.0, p=79614, mu_n=11.4 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=195, t=195.0, p=79786, mu_n=17.2 mu_factor=0.5, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=196, t=196.0, p=79823, mu_n=3.7 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=197, t=197.0, p=79840, mu_n=1.7 mu_factor=0.05, dI=0.00173, dg=0.0, K=-10.0 -> Open short
# iter=198, t=198.0, p=79977, mu_n=13.7 mu_factor=0.4, dI=-0.00173, dg=-137.0, K=10.0 -> Close short
# iter=199, t=199.0, p=79836, mu_n=-14.1 mu_factor=0.41, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=200, t=200.0, p=79534, mu_n=-30.2 mu_factor=0.87, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=201, t=201.0, p=79619, mu_n=8.5 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=202, t=202.0, p=79503, mu_n=-11.6 mu_factor=0.34, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=203, t=203.0, p=79420, mu_n=-8.3 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=204, t=204.0, p=79314, mu_n=-10.6 mu_factor=0.31, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=205, t=205.0, p=79219, mu_n=-9.5 mu_factor=0.27, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=206, t=206.0, p=79244, mu_n=2.5 mu_factor=0.07, dI=-0.00137, dg=0.0, K=10.0 -> Open long
# iter=207, t=207.0, p=79287, mu_n=4.3 mu_factor=0.12, dI=0.00137, dg=43.0, K=-10.0 -> Close long
# iter=208, t=208.0, p=79214, mu_n=-7.3 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=209, t=209.0, p=79334, mu_n=12.0 mu_factor=0.35, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=210, t=210.0, p=79278, mu_n=-5.6 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=211, t=211.0, p=79113, mu_n=-16.5 mu_factor=0.48, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=212, t=212.0, p=78986, mu_n=-12.7 mu_factor=0.37, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=213, t=213.0, p=79012, mu_n=2.6 mu_factor=0.08, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=214, t=214.0, p=79085, mu_n=7.3 mu_factor=0.21, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=215, t=215.0, p=79233, mu_n=14.8 mu_factor=0.43, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=216, t=216.0, p=79195, mu_n=-3.8 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=217, t=217.0, p=79366, mu_n=17.1 mu_factor=0.49, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=218, t=218.0, p=79371, mu_n=0.5 mu_factor=0.01, dI=-0.00043, dg=0.0, K=10.0 -> Open long
# iter=219, t=219.0, p=79208, mu_n=-16.3 mu_factor=0.47, dI=0.00043, dg=-163.0, K=-10.0 -> Close long
# iter=220, t=220.0, p=79240, mu_n=3.2 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=221, t=221.0, p=79288, mu_n=4.8 mu_factor=0.14, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=222, t=222.0, p=79420, mu_n=13.2 mu_factor=0.38, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=223, t=223.0, p=79603, mu_n=18.3 mu_factor=0.53, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=224, t=224.0, p=79672, mu_n=6.9 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=225, t=225.0, p=79614, mu_n=-5.8 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=226, t=226.0, p=79757, mu_n=14.3 mu_factor=0.41, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=227, t=227.0, p=79700, mu_n=-5.7 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=228, t=228.0, p=79299, mu_n=-40.1 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=229, t=229.0, p=79700, mu_n=40.1 mu_factor=1.0, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=230, t=230.0, p=79801, mu_n=10.1 mu_factor=0.25, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=231, t=231.0, p=79989, mu_n=18.8 mu_factor=0.47, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=232, t=232.0, p=80057, mu_n=6.8 mu_factor=0.17, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=233, t=233.0, p=80050, mu_n=-0.7 mu_factor=0.02, dI=0.00163, dg=0.0, K=10.0 -> Open long
# iter=234, t=234.0, p=79942, mu_n=-10.8 mu_factor=0.27, dI=-0.00163, dg=-108.0, K=-10.0 -> Close long
# iter=235, t=235.0, p=80138, mu_n=19.6 mu_factor=0.49, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=236, t=236.0, p=80025, mu_n=-11.3 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=237, t=237.0, p=80101, mu_n=7.6 mu_factor=0.19, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=238, t=238.0, p=80108, mu_n=0.7 mu_factor=0.02, dI=0.00108, dg=0.0, K=-10.0 -> Open short
# iter=239, t=239.0, p=80334, mu_n=22.6 mu_factor=0.56, dI=-0.00108, dg=-226.0, K=10.0 -> Close short
# iter=240, t=240.0, p=80313, mu_n=-2.1 mu_factor=0.05, dI=-0.00226, dg=0.0, K=-10.0 -> Open short
# iter=241, t=241.0, p=80150, mu_n=-16.3 mu_factor=0.41, dI=0.00226, dg=163.0, K=10.0 -> Close short
# iter=242, t=242.0, p=80188, mu_n=3.8 mu_factor=0.09, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=243, t=243.0, p=80239, mu_n=5.1 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=244, t=244.0, p=80350, mu_n=11.1 mu_factor=0.28, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=245, t=245.0, p=80244, mu_n=-10.6 mu_factor=0.26, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=246, t=246.0, p=80298, mu_n=5.4 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=247, t=247.0, p=80418, mu_n=12.0 mu_factor=0.3, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=248, t=248.0, p=80417, mu_n=-0.1 mu_factor=0.0, dI=0.00163, dg=0.0, K=10.0 -> Open long
# iter=249, t=249.0, p=80459, mu_n=4.2 mu_factor=0.1, dI=-0.00163, dg=42.0, K=-10.0 -> Close long
# iter=250, t=250.0, p=80525, mu_n=6.6 mu_factor=0.16, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=251, t=251.0, p=80570, mu_n=4.5 mu_factor=0.11, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=252, t=252.0, p=80701, mu_n=13.1 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=253, t=253.0, p=80751, mu_n=5.0 mu_factor=0.12, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=254, t=254.0, p=80569, mu_n=-18.2 mu_factor=0.45, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=255, t=255.0, p=80552, mu_n=-1.7 mu_factor=0.04, dI=-0.00042, dg=0.0, K=-10.0 -> Open short
# iter=256, t=256.0, p=80431, mu_n=-12.1 mu_factor=0.3, dI=0.00042, dg=121.0, K=10.0 -> Close short
# iter=257, t=257.0, p=80336, mu_n=-9.5 mu_factor=0.24, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=258, t=258.0, p=80528, mu_n=19.2 mu_factor=0.48, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=259, t=259.0, p=80140, mu_n=-38.8 mu_factor=0.97, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=260, t=260.0, p=79939, mu_n=-20.1 mu_factor=0.5, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=261, t=261.0, p=80184, mu_n=24.5 mu_factor=0.61, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=262, t=262.0, p=79822, mu_n=-36.2 mu_factor=0.9, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=263, t=263.0, p=79482, mu_n=-34.0 mu_factor=0.85, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=264, t=264.0, p=79254, mu_n=-22.8 mu_factor=0.57, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=265, t=265.0, p=79631, mu_n=37.7 mu_factor=0.94, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=266, t=266.0, p=79762, mu_n=13.1 mu_factor=0.33, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=267, t=267.0, p=79529, mu_n=-23.3 mu_factor=0.58, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=268, t=268.0, p=79803, mu_n=27.4 mu_factor=0.68, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=269, t=269.0, p=79724, mu_n=-7.9 mu_factor=0.2, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=270, t=270.0, p=79840, mu_n=11.6 mu_factor=0.29, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=271, t=271.0, p=80196, mu_n=35.6 mu_factor=0.89, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=272, t=272.0, p=80198, mu_n=0.2 mu_factor=0.0, dI=0.00121, dg=0.0, K=-10.0 -> Open short
# iter=273, t=273.0, p=80130, mu_n=-6.8 mu_factor=0.17, dI=-0.00121, dg=68.0, K=10.0 -> Close short
# iter=274, t=274.0, p=80298, mu_n=16.8 mu_factor=0.42, dI=0.0, dg=0.0, K=0.0 -> Hold
# iter=275, t=275.0, p=80278, mu_n=-2.0 mu_factor=0.05, dI=0.00068, dg=0.0, K=10.0 -> Open long
# iter=276, t=276.0, p=80307, mu_n=2.9 mu_factor=0.07, dI=-0.00068, dg=29.0, K=-10.0 -> Close long
# iter=277, t=277.0, p=80254, mu_n=-5.3 mu_factor=0.13, dI=0.0, dg=0.0, K=0.0 -> Hold
# Итоговая прибыль: 0.0

# %% [markdown]
# ## Alg0 v.0.1
#
# Работает в двух модификациях:
#
# 1) без добавления шума, когда g(t) = E_g(t), т.е. функция выигрыша равна своему матожиданию. В этом случае для положительных I_0, K всегда положительно или равно 0, и это чисто бычья стратегия. Для отрицательных I_0 K всегда отрицательно или равно 0, и это чисто медвежья стратегия. Т.е. нет смены знака по ходу выполнения алгоритма, каким бы ни был входной тренд.
#
# 2) к матожиданию процесса при вычислении функции g(t) мы добавляем нормальный белый шум N(0, 10). В этом случае появляется знакопеременность у K, и стратегия становится смешанной.

# %%
from math import fabs, exp
from scipy.optimize import minimize_scalar
import functools
import random


def minus_eg(k, _d_inv, _mu, _delta_t):
    """Функция Eg, которую мы максимизируем, взятая со знаком минус, потому что scipy.optimize ищет минимум."""
    res = -_mu/fabs(_mu)*_d_inv/k*(exp(k*_mu*_delta_t) + exp(-k*_mu*_delta_t) - 2.)
    return res


def calc_alg0(_p_arr, _mu_arr, di0):
    n_max = len(_p_arr) - 1
    # Ограничения на K
    k_min = -10
    k_max = 10
    # Массивы
    t_max = float(n_max) # /100
    t_arr = np.linspace(0., t_max, n_max + 1)
    #dt = t_arr[1]-t_arr[0]
    dt = 1
    k_arr = np.zeros(n_max+1)
    dg_arr = np.zeros(n_max+1)
    di_arr = np.zeros(n_max+1)
    di_arr[0] = di0    
    # print('Starting alg0, I_0 = ', di0)    
    for i in range(1, n_max-1):
        des_str = ''
        if fabs(_mu_arr[i]) <= .1:
            k_arr[i] = 0.
            dg_arr[i] = 0.
            des_str = 'Nothing'
            di_arr[i+1] = 0. 
        else:            
            mu_normalized = _mu_arr[i]/10
            minus_eg_cur = functools.partial(minus_eg, _d_inv=di_arr[i], _mu = mu_normalized, _delta_t=dt)
            """k_line = np.linspace(k_min, k_max, 100)
            f = np.array([minus_eg_cur(k)for k in k_line])
            plt.plot(k_line, f)
            plt.show()"""
            k_cur = minimize_scalar(minus_eg_cur, bounds=(k_min, k_max), method='bounded').x 
            k_arr[i] = k_cur
            dg_arr[i] = k_cur/fabs(k_cur)*(_p_arr[i] - _p_arr[i-1])
            
            if dg_arr[i] < 20:
                k_arr[i] = 0.
                dg_arr[i] = 0.
                di_arr[i] = 0.
                des_str = 'Nothing'
            else: 
                if k_cur >= 0:
                    des_str = 'Buy'
                else:
                    des_str = 'Sell'    
            di_arr[i+1] = di_arr[i] + k_arr[i]*dg_arr[i]
            if i <= 10:
                # print(f'iter={i}, t={round(t_arr[i], 2)}, I={round(di_arr[i], 4)}, mu={round(mu_normalized, 4)}',
                #      f'g={round(dg_arr[i], 4)}, K={round(k_arr[i], 4)} -> {des_str}')    
                pass
    dk_ser = pd.Series(k_arr[:-2], index=t_arr[:-2])
    dg_ser = pd.Series(dg_arr[:-2], index=t_arr[:-2])
    di_ser = pd.Series(di_arr[:-2], index=t_arr[:-2])
    # print(di_arr)
    plt.figure(figsize=(20, 3))
    
    n_lst = list(range(len(_p_arr)))
    plt.subplot(141)
    plt.title("Price") # заголовок
    plt.xlabel("n") # ось абсцисс
    plt.ylabel("p_n") # ось ординат
    plt.grid()      # включение отображение сетки
    # plt.plot(p_ser)  # построение графика
    plt.plot(n_lst, _p_arr)
    plt.legend(['p_n'], loc="upper left")
    plt.subplot(142)
    plt.plot(dg_ser[:n_max-2], marker='o')
    plt.xlabel("t")
    plt.ylabel("dg")
    plt.title("Current profit")
    plt.grid()     
    plt.subplot(143)
    plt.plot(di_ser[:n_max-2], marker='o')
    plt.xlabel("t")
    plt.ylabel("dI")
    plt.title("Current investment")
    plt.grid()     
    plt.subplot(144)
    plt.plot(k_arr[:n_max-2])
    plt.xlabel("t")
    plt.ylabel("K")
    plt.title("PID Gain coefficient")
    plt.grid()
    plt.show()        
    
    plt.figure(figsize=(20, 3))
    # plt.tight_layout()
    plt.subplot(141)
    plt.title("Trend modeling by first difference") # заголовок
    plt.xlabel("n") # ось абсцисс
    plt.ylabel("mu") # ось ординат
    plt.grid()      # включение отображение сетки
    plt.plot(n_lst, _mu_arr, color='orange')
    plt.legend(['mu'], loc="upper left")
    plt.subplot(142)
    plt.plot(np.cumsum(dg_ser[:n_max-2]), color='orange')
    plt.xlabel("t")
    plt.ylabel("g")
    plt.title("Cumulative profit")
    plt.grid()     
    plt.subplot(143)
    plt.plot(np.cumsum(di_ser[:n_max-2]), color='orange')
    plt.xlabel("t")
    plt.ylabel("I")
    plt.title("Cumulative investment")
    plt.grid()     
    plt.subplot(144)
    plt.plot(k_arr[:n_max-2])
    plt.xlabel("t")
    plt.ylabel("K")
    plt.title("(technical plot 1)")
    plt.grid()
    # plt.subplots_adjust(wspace=0, hspace=0)
    plt.show()    
    
    figure = plt.figure(figsize=(10, 3))
    plt.title("Decision Buy/Sell/Do nothing (zoomed)") # заголовок
    plt.xlabel("n") # ось абсцисс
    plt.ylabel("K_n") # ось ординат
    plt.grid()      # включение отображение сетки
    # plt.plot(p_ser)  # построение графика
    plt.plot(n_lst[50:101], k_arr[50:101])
    plt.plot(n_lst[50:101], (_p_arr[50:101]-_p_arr.mean())/_p_arr.std()*50)
    plt.legend(['k_arr','p_n'], loc="upper left")
    
#    print(list(dg_ser))
#    print(list(np.cumsum(dg_ser)))
    
    

"""
# Три разных случая
# 1. I_0 > 0, g(t) = Eg(t) -> I_0 = 10, xi = 0
print('1. I_0 > 0, g(t) = Eg(t) -> I_0 = 10, xi = 0:')
calc_alg0(p_arr, mu_arr, 10)
print('='*10)
print()
print()

# 2. I_0 < 0, g(t) = Eg(t) -> I_0 = -10, xi = 0
print('2. I_0 < 0, g(t) = Eg(t) -> I_0 = -10, xi = 0:')
calc_alg0(p_arr, mu_arr, -10)
print('='*10)
print()
print()

# 3. I_0 любое, g(t) = Eg(t) + xi(t) (белый шум) -> I_0 = 10, xi_noise = 10, lambda: .1*np.random.normal(0, 1)    
print('3. I_0=10, g(t) = Eg(t) + xi(t) (белый шум) -> I_0 = 10, xi_noise -- белый шум 0.1*N(0,1):')
xi_noise = lambda: .1*np.random.normal(0, 1)  
calc_alg0(p_arr, mu_arr, 10, xi_noise)    
print('='*10)
print()
print()
"""

# di0 = 1
# xi_noise = lambda: -10.*np.random.normal(0, 20)  
# calc_alg0(p_arr_si_21[:200], mu_arr_si_21[:200], 1)
print('Real data USD 16.02.2022:')
calc_alg0(p_arr_arma, mu_arr_arma, 1)
# p_arr_stable
# Out:
# Real data USD 16.02.2022:

# %%
print('Real data USD 17.02.2022:')
calc_alg0(p_arr_growth, mu_arr_growth, 1)
# Out:
# Real data USD 17.02.2022:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 print('Real data USD 17.02.2022:')
# ----> 2 calc_alg0(p_arr_growth, mu_arr_growth, 1)
#
# Input In [8], in calc_alg0(_p_arr, _mu_arr, di0)
#      34     di_arr[i+1] = 0.
#      35 else:
# ---> 36     mu_normalized = mu_arr[i]/10
#      37     minus_eg_cur = functools.partial(minus_eg, _d_inv=di_arr[i], _mu = mu_normalized, _delta_t=dt)
#      38     """k_line = np.linspace(k_min, k_max, 100)
#      39     f = np.array([minus_eg_cur(k)for k in k_line])
#      40     plt.plot(k_line, f)
#      41     plt.show()"""
#
# IndexError: index 101 is out of bounds for axis 0 with size 101

# %%
print('Real data USD 14.02.2022:')
calc_alg0(p_arr_si_14, mu_arr_si_14, 1)
# Out:
# Real data USD 14.02.2022:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 print('Real data USD 14.02.2022:')
# ----> 2 calc_alg0(p_arr_si_14, mu_arr_si_14, 1)
#
# Input In [8], in calc_alg0(_p_arr, _mu_arr, di0)
#      34     di_arr[i+1] = 0.
#      35 else:
# ---> 36     mu_normalized = mu_arr[i]/10
#      37     minus_eg_cur = functools.partial(minus_eg, _d_inv=di_arr[i], _mu = mu_normalized, _delta_t=dt)
#      38     """k_line = np.linspace(k_min, k_max, 100)
#      39     f = np.array([minus_eg_cur(k)for k in k_line])
#      40     plt.plot(k_line, f)
#      41     plt.show()"""
#
# IndexError: index 101 is out of bounds for axis 0 with size 101

# %%
print('Real data USD 21.02.2022:')

calc_alg0(p_arr_si_21[:200], mu_arr_si_21[:200], 1)
# Out:
# Real data USD 21.02.2022:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [16], in <cell line: 3>()
#       1 print('Real data USD 21.02.2022:')
# ----> 3 calc_alg0(p_arr_si_21[:200], mu_arr_si_21[:200], 1)
#
# Input In [11], in calc_alg0(_p_arr, _mu_arr, di0)
#      34     di_arr[i+1] = 0.
#      35 else:
# ---> 36     mu_normalized = mu_arr[i]/10
#      37     minus_eg_cur = functools.partial(minus_eg, _d_inv=di_arr[i], _mu = mu_normalized, _delta_t=dt)
#      38     """k_line = np.linspace(k_min, k_max, 100)
#      39     f = np.array([minus_eg_cur(k)for k in k_line])
#      40     plt.plot(k_line, f)
#      41     plt.show()"""
#
# IndexError: index 101 is out of bounds for axis 0 with size 101

# %%
mu_arr
# Out:
# array([ 0.        ,  0.03095793,  2.50844352, -4.81308732, -1.96300962,
#         5.48913116, -5.79723521,  4.29451599,  5.01936814, -4.29197341,
#         2.68887264, -5.5939089 , -0.11416015,  6.11896882, -2.76097145,
#        -6.16521296,  8.3734904 , -3.06864322,  4.74199812, -7.50157777,
#         5.97892345, -2.66525697, -1.19256346, -3.34523362,  6.7797146 ,
#         0.89503466, -0.95607312, -4.25106082, -3.61241913,  7.06212333,
#         0.64210151, -2.04970131, -2.05376084,  1.39291497,  2.11018231,
#        -3.35424348, -2.79683487,  7.52852724, -3.90439901,  1.77051453,
#        -5.11368323,  6.33181109,  0.57972159, -1.15051842,  0.14067607,
#        -6.1358846 ,  1.69140546,  2.43606178,  2.43788641, -1.85118113,
#         4.49246088, -6.63233443, -0.25621455, -0.27066691, -0.20908865,
#         4.83227059, -6.19183905,  1.5766157 , -1.40957478,  6.45860116,
#         0.47560611, -8.84678723,  4.83899632,  2.16036634,  1.44155102,
#        -8.05068847,  2.01557366, -1.74465627,  7.64029379, -3.13416319,
#        -2.14460989,  1.8054743 , -2.70826421,  6.76596694, -7.01035681,
#         1.11427882,  1.39468445,  0.29903384,  0.67090028,  1.92417042,
#        -4.68203634, -0.83338984,  2.8684346 , -1.20223079, -1.32326861,
#        -1.32455415,  5.27356393, -3.50728135,  6.06187113, -5.65499814,
#         2.35598796, -5.21791141,  2.59214808, -0.85148529,  1.6798474 ,
#         7.1558811 , -1.62655791, -1.47191725, -3.43106888,  0.53567828,
#        -0.97957173])

# %%
import math
import scipy
from scipy.optimize import minimize

def minus_eg_pi(k_vect, di=1, mu=-1, dt=1):
    k_p = k_vect[0]
    k_i = k_vect[1]
    """Функция Eg, которую мы максимизируем, взятая со знаком минус, потому что scipy.optimize ищет минимум."""
    if mu*mu*k_p*k_p + 4.*mu*k_i < 0:
        return 0.
    if mu*mu*k_p*k_p - 4.*mu*k_i < 0:
        return 0.
    if k_p*k_p + k_i*k_i > 10:
        return 0.
    alpha = math.sqrt(mu*mu*k_p*k_p + 4.*mu*k_i) / 2. 
    beta = math.sqrt(mu*mu*k_p*k_p - 4.*mu*k_i) / 2.
    comp1, comp2 = 0., 0.
    if alpha != 0.:
        comp1 = exp(mu*k_p*dt)*math.sinh(alpha*dt)/alpha
    else:
        comp1 = 1.
    if beta != 0.:
        comp2 = math.sinh(beta*dt)/beta
    else:
        comp2 = 1.    
    
    res = - mu*di*exp(-mu*k_p*dt/2.) * (comp1 - comp2)
    return res
       
    
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

_x = np.linspace(-4., 4., 100)
_y = np.linspace(-4., 4., 100)

x, y = np.meshgrid(_x, _y)

plt.xlabel('x')
plt.ylabel('y')

# print(x, y)
# mu=6.1 k_cur_arr=[0. 0.] Kp=0.0 Ki=0.0 I=-84.74089 
z = np.array([[minus_eg_pi((_x[i], _y[j]), di=-84.74089, mu=6.1, dt=1.) for i in range(100)] for j in range(100)])
ax.plot_surface(x, y, z)
plt.show()    
    


"""
def ineq_constraint1(k_p, k_i, mu=1):
    return mu*mu*k_p*k_p - 4.*mu*k_i

def ineq_constraint2(k_p, k_i, mu=1):
    return mu*mu*k_p*k_p + 4.*mu*k_i

def ineq_constraint3(k_p, k_i):
    return k_p*k_p + k_i*k+i - 10.
"""

"""
# def ineq_cons(k_p, k_i, mu=1):
#    return [mu*mu*k_p*k_p - 4.*mu*k_i, mu*mu*k_p*k_p + 4.*mu*k_i, k_p*k_p + k_i*k+i - 10.]

def ineq_cons(k_p, k_i):
    k_p*k_p + k_i*k+i - 10.

# con = scipy.optimize.NonlinearConstraint(ineq_cons, -4., 4.)
b = (-4., 4.)
minus_eg_pi_cur = functools.partial(minus_eg_pi, di = 1., mu = -4.13, dt = 1.)
print(minimize(minus_eg_pi_cur, x0=[0., 0.], method='COBYLA', bounds=b).x)
"""    
    

def calc_alg1(_p_arr, _mu_arr, di0):
    n_max = len(_p_arr) - 1
    # Ограничения на K
    k_min = -4.
    k_max = 4.
    # Массивы
    t_max = float(n_max) # /100
    t_arr = np.linspace(0., t_max, n_max + 1)
    #dt = t_arr[1]-t_arr[0]
    dt = 1
    k_p_arr = np.zeros(n_max+1)
    k_i_arr = np.zeros(n_max+1)
    dg_arr = np.zeros(n_max+1)
    di_arr = np.zeros(n_max+1)
    di_arr[0] = di0    
    di_arr[1] = di0   
    # print('Starting alg0, I_0 = ', di0)    
    for i in range(1, n_max-1):
        des_str = ''
        if fabs(_mu_arr[i]) <= .1:
            k_p_arr[i] = 0.
            k_i_arr[i] = 0.
            dg_arr[i] = 0.
            des_str = 'Nothing'
            di_arr[i+1] = 0. 
        else:            
            mu_normalized = _mu_arr[i]/10.
            b = (k_min, k_max)
            sign_mu = mu_normalized/fabs(mu_normalized)
            minus_eg_pi_cur = functools.partial(minus_eg_pi, di = di_arr[i-1], mu = mu_normalized, dt = 1.)
            k_cur_arr = minimize(minus_eg_pi_cur, x0=[sign_mu*3.1, 0.], method='COBYLA', bounds=b).x
            # print(k_cur_tpl)
            k_p_arr[i], k_i_arr[i] = k_cur_arr[0], k_cur_arr[1]
            dg_arr[i] = k_p_arr[i]/fabs(k_p_arr[i])*(_p_arr[i] - _p_arr[i-1])
            integ = 0.
            if i <= 10:
                k_i_arr[i] = 0.
                if k_p_arr[i] >= 0.:
                    des_str = 'Buy'
                else:
                    des_str = 'Sell'           
            else:
                integ = 0
                for cnt in range(10):
                    integ += dg_arr[i-cnt]*exp(-3.14159*cnt*dt)   
                # Decision
                if k_p_arr[i]*k_i_arr[i] >= 0 and k_cur_arr[1] >= 0:
                    des_str = 'Buy'
                elif k_cur_arr[0] < 0 and k_cur_arr[1] < 0:
                    des_str = 'Sell'
                else:
                    des_str = 'Nothing'   
            # Если прибыль падает близко к 0, уходим    
            # if dg_arr[i] < 20.:
            #    k_p_arr[i] = 0.
            #    k_i_arr[i] = 0.
            #    dg_arr[i] = 0.
            #    di_arr[i] = 0.
            #    des_str = 'Nothing'
            # else:            
            di_arr[i+1] = di_arr[i] + k_p_arr[i]*dg_arr[i] + k_i_arr[i]*integ
            if i <= 10:
                print(f'iter={i} t={round(t_arr[i], 2)} mu={round(mu_normalized, 5)} k_cur_arr={k_cur_arr}', 
                    f'Kp={round(k_p_arr[i], 5)} Ki={round(k_i_arr[i], 5)} I={round(di_arr[i], 5)}', 
                    f'g={round(dg_arr[i], 5)} -> {des_str}')   
                    # pass
    dkp_ser = pd.Series(k_p_arr[:-2], index=t_arr[:-2])
    dki_ser = pd.Series(k_i_arr[:-2], index=t_arr[:-2])
    dg_ser = pd.Series(dg_arr[:-2], index=t_arr[:-2])
    di_ser = pd.Series(di_arr[:-2], index=t_arr[:-2])
    # print(di_arr)
    plt.figure(figsize=(20, 3))
    
    n_lst = list(range(len(_p_arr)))
    plt.subplot(141)
    plt.title("Price") # заголовок
    plt.xlabel("n") # ось абсцисс
    plt.ylabel("p_n") # ось ординат
    plt.grid()      # включение отображение сетки
    # plt.plot(p_ser)  # построение графика
    plt.plot(n_lst, _p_arr)
    plt.legend(['p_n'], loc="upper left")
    plt.subplot(142)
    plt.plot(dg_ser[:n_max-2], marker='o')
    plt.xlabel("t")
    plt.ylabel("dg")
    plt.title("Current profit")
    plt.grid()     
    plt.subplot(143)
    plt.plot(di_ser[:n_max-2], marker='o')
    plt.xlabel("t")
    plt.ylabel("dI")
    plt.title("Current investment")
    plt.grid()     
    plt.subplot(144)
    plt.plot(k_p_arr[:n_max-2])
    plt.xlabel("t")
    plt.ylabel("K")
    plt.title("PID Gain coefficient")
    plt.grid()
    plt.show()        
    
    plt.figure(figsize=(20, 3))
    # plt.tight_layout()
    plt.subplot(141)
    plt.title("Trend modeling by first difference") # заголовок
    plt.xlabel("n") # ось абсцисс
    plt.ylabel("mu") # ось ординат
    plt.grid()      # включение отображение сетки
    plt.plot(n_lst, _mu_arr, color='orange')
    plt.legend(['mu'], loc="upper left")
    plt.subplot(142)
    plt.plot(np.cumsum(dg_ser[:n_max-2]), color='orange')
    plt.xlabel("t")
    plt.ylabel("g")
    plt.title("Cumulative profit")
    plt.grid()     
    plt.subplot(143)
    plt.plot(np.cumsum(di_ser[:n_max-2]), color='orange')
    plt.xlabel("t")
    plt.ylabel("I")
    plt.title("Cumulative investment")
    plt.grid()     
    plt.subplot(144)
    plt.plot(k_p_arr[:n_max-2])
    plt.xlabel("t")
    plt.ylabel("K")
    plt.title("(technical plot 1)")
    plt.grid()
    # plt.subplots_adjust(wspace=0, hspace=0)
    plt.show()    
    
    figure = plt.figure(figsize=(10, 3))
    plt.title("Decision Buy/Sell/Do nothing (zoomed)") # заголовок
    plt.xlabel("n") # ось абсцисс
    plt.ylabel("K_n") # ось ординат
    plt.grid()      # включение отображение сетки
    # plt.plot(p_ser)  # построение графика
    plt.plot(n_lst[50:101], k_p_arr[50:101])
    plt.plot(n_lst[50:101], (_p_arr[50:101]-_p_arr.mean())/_p_arr.std())
    plt.legend(['k_arr','p_n'], loc="upper left")
    
calc_alg1(p_arr_growth, mu_arr_growth, 1.)
# Out:
# C:\Python310\lib\site-packages\scipy\optimize\_minimize.py:564: RuntimeWarning: Method COBYLA cannot handle bounds.
#   warn('Method %s cannot handle bounds.' % method,
# iter=1 t=1.0 mu=34.1 k_cur_arr=[ 3.16212897 -0.00772444] Kp=3.16213 Ki=0.0 I=1.0 g=341.0 -> Buy
# iter=2 t=2.0 mu=-0.5 k_cur_arr=[-2.1  1. ] Kp=-2.1 Ki=0.0 I=1079.28598 g=5.0 -> Sell
# iter=3 t=3.0 mu=6.3 k_cur_arr=[3.16227372 0.00844754] Kp=3.16227 Ki=0.0 I=1068.78598 g=63.0 -> Buy
# iter=4 t=4.0 mu=-0.6 k_cur_arr=[-2.1  1. ] Kp=-2.1 Ki=0.0 I=1268.00922 g=6.0 -> Sell
# iter=5 t=5.0 mu=6.7 k_cur_arr=[3.16213085 0.00848486] Kp=3.16213 Ki=0.0 I=1255.40922 g=67.0 -> Buy
# iter=6 t=6.0 mu=-0.6 k_cur_arr=[-2.1  1. ] Kp=-2.1 Ki=0.0 I=1467.27199 g=6.0 -> Sell
# iter=7 t=7.0 mu=-6.3 k_cur_arr=[-0.65620094  1.23123527] Kp=-0.6562 Ki=0.0 I=1454.67199 g=63.0 -> Sell
# iter=8 t=8.0 mu=3.4 k_cur_arr=[3.16221276 0.00874658] Kp=3.16221 Ki=0.0 I=1413.33133 g=34.0 -> Buy
# iter=9 t=9.0 mu=2.4 k_cur_arr=[3.1623405  0.00569377] Kp=3.16234 Ki=0.0 I=1520.84657 g=24.0 -> Buy
# iter=10 t=10.0 mu=-14.9 k_cur_arr=[-0.10742655  1.27872666] Kp=-0.10743 Ki=0.0 I=1596.74274 g=149.0 -> Sell

# %%
calc_alg1(p_arr_stable, mu_arr_stable, 1.)
# Out:
# C:\Python310\lib\site-packages\scipy\optimize\_minimize.py:564: RuntimeWarning: Method COBYLA cannot handle bounds.
#   warn('Method %s cannot handle bounds.' % method,
# iter=1 t=1.0 mu=-13.1 k_cur_arr=[-0.54173254  1.02893973] Kp=-0.54173 Ki=0.0 I=1.0 g=131.0 -> Sell
# iter=2 t=2.0 mu=-2.6 k_cur_arr=[-1.10057064  1.03377802] Kp=-1.10057 Ki=0.0 I=-69.96696 g=26.0 -> Sell
# iter=3 t=3.0 mu=8.5 k_cur_arr=[4.1 0. ] Kp=4.1 Ki=0.0 I=-98.5818 g=85.0 -> Buy
# iter=4 t=4.0 mu=-0.9 k_cur_arr=[-3.16201178 -0.02912489] Kp=-3.16201 Ki=0.0 I=249.9182 g=9.0 -> Sell
# iter=5 t=5.0 mu=-11.1 k_cur_arr=[-0.66346781  1.24381047] Kp=-0.66347 Ki=0.0 I=221.46009 g=111.0 -> Sell
# iter=6 t=6.0 mu=2.9 k_cur_arr=[ 3.1623495  -0.00493909] Kp=3.16235 Ki=0.0 I=147.81517 g=29.0 -> Buy
# iter=7 t=7.0 mu=3.2 k_cur_arr=[3.16137983 0.06745423] Kp=3.16138 Ki=0.0 I=239.5233 g=32.0 -> Buy
# iter=8 t=8.0 mu=-0.2 k_cur_arr=[-2.1  1. ] Kp=-2.1 Ki=0.0 I=340.68746 g=2.0 -> Sell
# iter=9 t=9.0 mu=-4.3 k_cur_arr=[-0.64973111  1.22389143] Kp=-0.64973 Ki=0.0 I=336.48746 g=43.0 -> Sell
# iter=10 t=10.0 mu=-2.3 k_cur_arr=[-1.10101598  1.04506571] Kp=-1.10102 Ki=0.0 I=308.54902 g=23.0 -> Sell

# %%
calc_alg1(p_arr_si_14, mu_arr_si_14, 1.)
# Out:
# C:\Python310\lib\site-packages\scipy\optimize\_minimize.py:564: RuntimeWarning: Method COBYLA cannot handle bounds.
#   warn('Method %s cannot handle bounds.' % method,
# iter=1 t=1.0 mu=41.3 k_cur_arr=[3.16216724 0.00539148] Kp=3.16217 Ki=0.0 I=1.0 g=413.0 -> Buy
# iter=2 t=2.0 mu=-2.9 k_cur_arr=[-1.10032053  1.02531725] Kp=-1.10032 Ki=0.0 I=1306.97507 g=29.0 -> Sell
# iter=3 t=3.0 mu=19.6 k_cur_arr=[3.16232268 0.01575938] Kp=3.16232 Ki=0.0 I=1275.06577 g=196.0 -> Buy
# iter=4 t=4.0 mu=34.3 k_cur_arr=[ 3.16216626 -0.00758639] Kp=3.16217 Ki=0.0 I=1894.88102 g=343.0 -> Buy
# iter=5 t=5.0 mu=-11.2 k_cur_arr=[-0.66355523  1.24396618] Kp=-0.66356 Ki=0.0 I=2979.50405 g=112.0 -> Sell
# iter=6 t=6.0 mu=-9.8 k_cur_arr=[-0.6621695   1.24149225] Kp=-0.66217 Ki=0.0 I=2905.18586 g=98.0 -> Sell
# iter=7 t=7.0 mu=-16.0 k_cur_arr=[-0.10812641  1.28095919] Kp=-0.10813 Ki=0.0 I=2840.29325 g=160.0 -> Sell
# iter=8 t=8.0 mu=9.0 k_cur_arr=[3.16232114 0.00934343] Kp=3.16232 Ki=0.0 I=2822.99303 g=90.0 -> Buy
# iter=9 t=9.0 mu=-3.2 k_cur_arr=[-1.10017992  1.01896863] Kp=-1.10018 Ki=0.0 I=3107.60193 g=32.0 -> Sell
# iter=10 t=10.0 mu=2.7 k_cur_arr=[3.16159661 0.06862254] Kp=3.1616 Ki=0.0 I=3072.39617 g=27.0 -> Buy

# %%
calc_alg1(p_arr_si_21, mu_arr_si_21, 1.)
# Out:
# C:\Python310\lib\site-packages\scipy\optimize\_minimize.py:564: RuntimeWarning: Method COBYLA cannot handle bounds.
#   warn('Method %s cannot handle bounds.' % method,
# iter=1 t=1.0 mu=23.7 k_cur_arr=[ 3.16226647 -0.0170508 ] Kp=3.16227 Ki=0.0 I=1.0 g=237.0 -> Buy
# iter=2 t=2.0 mu=1.4 k_cur_arr=[3.16187423 0.04125712] Kp=3.16187 Ki=0.0 I=750.45715 g=14.0 -> Buy
# iter=3 t=3.0 mu=-12.9 k_cur_arr=[-0.54171754  1.02864904] Kp=-0.54172 Ki=0.0 I=794.72339 g=129.0 -> Sell
# iter=4 t=4.0 mu=-3.2 k_cur_arr=[-1.10017992  1.01896863] Kp=-1.10018 Ki=0.0 I=724.84183 g=32.0 -> Sell
# iter=5 t=5.0 mu=8.2 k_cur_arr=[ 3.16231089 -0.00803526] Kp=3.16231 Ki=0.0 I=689.63607 g=82.0 -> Buy
# iter=6 t=6.0 mu=6.7 k_cur_arr=[3.16212657 0.01167931] Kp=3.16213 Ki=0.0 I=948.94557 g=67.0 -> Buy
# iter=7 t=7.0 mu=0.8 k_cur_arr=[3.16212568 0.01441691] Kp=3.16213 Ki=0.0 I=1160.80805 g=8.0 -> Buy
# iter=8 t=8.0 mu=-5.8 k_cur_arr=[-0.65486383  1.22922619] Kp=-0.65486 Ki=0.0 I=1186.10505 g=58.0 -> Sell
# iter=9 t=9.0 mu=-9.0 k_cur_arr=[-0.66118702  1.2397374 ] Kp=-0.66119 Ki=0.0 I=1148.12295 g=90.0 -> Sell
# iter=10 t=10.0 mu=-14.4 k_cur_arr=[-0.10705846  1.27756745] Kp=-0.10706 Ki=0.0 I=1088.61612 g=144.0 -> Sell

# %%
calc_alg1(p_arr_arma, mu_arr_arma, 1.)
# Out:
# C:\Python310\lib\site-packages\scipy\optimize\_minimize.py:564: RuntimeWarning: Method COBYLA cannot handle bounds.
#   warn('Method %s cannot handle bounds.' % method,
# iter=1 t=1.0 mu=-1.00822 k_cur_arr=[-1.11271491  1.15895958] Kp=-1.11271 Ki=0.0 I=1.0 g=10.08224 -> Sell
# iter=3 t=3.0 mu=-0.91165 k_cur_arr=[-3.16202445 -0.04524447] Kp=-3.16202 Ki=0.0 I=0.0 g=9.11647 -> Sell
# iter=4 t=4.0 mu=3.62523 k_cur_arr=[3.1 0. ] Kp=3.1 Ki=0.0 I=-28.82649 g=36.25226 -> Buy
# iter=5 t=5.0 mu=-2.09764 k_cur_arr=[-3.15274181  0.24427813] Kp=-3.15274 Ki=0.0 I=83.5555 g=20.97642 -> Sell
# iter=6 t=6.0 mu=-0.96269 k_cur_arr=[-1.11391561  1.16624554] Kp=-1.11392 Ki=0.0 I=17.42227 g=9.62691 -> Sell
# iter=7 t=7.0 mu=3.38012 k_cur_arr=[3.16221255 0.00875682] Kp=3.16221 Ki=0.0 I=6.69871 g=33.80117 -> Buy
# iter=8 t=8.0 mu=-4.15104 k_cur_arr=[-0.64912076  1.2236257 ] Kp=-0.64912 Ki=0.0 I=113.5852 g=41.51043 -> Sell
# iter=9 t=9.0 mu=3.02499 k_cur_arr=[3.16235388 0.0089078 ] Kp=3.16235 Ki=0.0 I=86.63991 g=30.24989 -> Buy
# iter=10 t=10.0 mu=-1.67548 k_cur_arr=[-1.10340082  1.08240196] Kp=-1.1034 Ki=0.0 I=182.30076 g=16.75482 -> Sell
